# %%
import sys
import string
import simplejson
import random
import statistics
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
#data = np.random.randn(1000)
def Rmatch(s,i,j):
    #search string s for substring BEGINNING
    #at position i, of length j
    #if (i+j+1 > len(s)):
    #    return([0,0])
    #else:
    return(s[:i+j-1].find(s[i:i+j]))

def Nmatch(s,i):
    j = 1
    ans = -1
    old = -1
    new = Rmatch(s,i,j)
    while ((new != -1) and (i+j-1 < len(s))):
        old = new
        j = j + 1
        new = Rmatch(s,i,j)
    return([old,j-1])

def Smatch(s,i): # i is an index (in L)
    temp = s[i]
    j = i
    pos = s[:j].find(temp)
    while ((pos > -1) and (i < len(s) -1)):
        i = i + 1
        temp = temp + s[i]
        pos = s[:j].find(temp)
        #print(temp,' found at position ',pos)
    if (len(temp) > 1):
        #return([s[:j].find(temp[:-1]),len(temp)-1])
        if (i == len(s) -1):
            return([pos,len(temp)])
        else:
            return([s[:j].find(temp[:-1]),len(temp)-1])
    else:
        return([pos, len(temp)])

def StringM(letters):
    str2 = letters.translate({ord(d): None for d in string.whitespace})
    print(str2)
    a = ''
    number_of_characters = 10000
    for i in range(number_of_characters):
        a += chr(random.randint(97, 122))
    ring = str2
    j=1
    new = [ring[0]]
    newA = [ring[0]]
    while (j < len(ring)):
        temp = Nmatch(ring,j)
        if (temp[0] == -1):
            new = new + [ring[j]]
            newA = newA + [ring[j]]
            j = j+1
        else:
            if (temp[1]<2):
                #don't bother indexing
                new = new + [ring[j:j+temp[1]]]
                newA = newA + [ring[temp[0]:(temp[0]+temp[1])]]
            else:
                new = new + [temp]
                newA = newA + [ring[temp[0]:(temp[0]+temp[1])]]
            j = j + temp[1]
    print(new)
    print(newA)
    print(ring)
    return([new,newA,ring])

def process(sent1):
    str2 = sent1.translate({ord(c): None for c in string.whitespace})
    print(str2)
    str3 = str2.replace("|","")
    #print(str3)
    str3a = str3.replace(":","")
    str4 = str3a.replace("~","")
    #print(str4)
    u = 1
    v = len(str4)-1
    while ((str4.find('(3',u,v)) != -1):
        #print("u= ",u," v= ",v)
        w = str4.find('(3',u,v)
        #print(w)
        #temp = str4[w+2]+str4[w+4]
        str4 = str4[:w] + str4[w+2] + str4[w+4:]
        #str4 = str4.replace("(3",temp,1)
        #print(str4)
        #print("found 2 at position ",w)
        u = w + 1
    u = 1
    v = len(str4)-1
    while ((str4.find('2',u,v)) != -1):
        #print("u= ",u," v= ",v)
        w = str4.find('2',u,v)
        #print(w)
        str4 = str4.replace("2",str4[w-1],1)
        #print(str4)
        #print("found 2 at position ",w)
        u = w + 1
    u = 1
    v = len(str4)-1
    while ((str4.find('4',u,v)) != -1):
        #print("u= ",u," v= ",v)
        w = str4.find('4',u,v)
        #print(w)
        temp = 3*str4[w-1]
        #print(temp)
        str4 = str4.replace("4",temp,1)
        #print(str4)
        #print("found 4 at position ",w)
        u = w + 1
    u = 1
    v = len(str4)-1
    while ((str4.find('3',u,v)) != -1):
        #print("u= ",u," v= ",v)
        w = str4.find('3',u,v)
        #print(w)
        temp = 2*str4[w-1]
        #print(temp)
        str4 = str4.replace("3",temp,1)
        #print(str4)
        #print("found 3 at position ",w)
        u = w + 1
    print(str4[-1])
    if (str4[-1] == '2'):
        str4 = str4[:-1] + str4[-2]
    if (str4[-1] == '4'):
        str4 = str4[:-1] + 3*str4[-2]
    if (str4[-1] == '3'):
        str4 = str4[:-1] + 2*str4[-2]
    return(str4)
    
fp = open("reels.txt")
fo = open("reelOutput.txt", "w")
#f.write("Now the file has more content!")
#f.close()
ind = []
for i, line in enumerate(fp):
    if line[0] == 'T':
        print(line)
        # 26th line
    elif line[0] == 'K':
        ind = ind + [i]
fp.close()
#print(ind)
tune = []
for k in ind:
    tune = tune + [k+1] + [k+2] + [k+3] + [k+4]
#print(tune)

fp = open("reels.txt")
ostats = []
stats = []
ratio = []
C = 0
str = ""
titles = []
for i, line in enumerate(fp):
    if line[0] == 'T':
        fo.write(line[2:])
        titles = titles + [line[2:]]
    if i in tune:
        C = C+1
        str = str + line[:-1]
        if (C == 4):
            print(str)
            fo.write(str+"\n")
            ab = process(str)
            print(ab)
            fo.write(ab+"\n")
            cd = StringM(ab)
            print(cd)
            #fo.writelines(cd[0])
            #fo.writelines(cd[1])
            #fo.writelines(cd[1]+"\n")
            fo.write(' '.join(cd[1])+"\n")
            lcd0 = len(cd[0])
            lcd1 = len(cd[1])
            lcd2 = len(cd[2])
            for k in range(lcd0):
                fo.write("%s," % cd[0][k])
            #fo.write(' '.join(cd[0])+"\n")
            #for x in cd[1]:
            #    print(x,file=fo)
            #fo.write('%03d\n' % len(cd[0]))
            fo.write('\n%03d***' % lcd1)
            fo.write('%03d\n' % lcd2)
            #ostats == ostats + [lcd2]
            #ostats == ostats + [12]
            if lcd2 == 128:
                #titles = titles + [line[2:]]
                stats = stats + [lcd1]
                ostats = ostats + [lcd2]
                ratio = ratio + [round(128/lcd1,2)]
            else:
                ostats = ostats + [lcd2]   
            #fo.write(str(len(cd[0]))+"\t"+str(len(cd[1]))+"\t"+str(len(cd[2])))
            print(len(cd[0]),len(cd[1]),len(cd[2]))
            fo.write("\n"+"\n")
            C=0
            str=""
    #if (line[0] == 'T' and lcd2 == 128):
        #fo.write(line[2:])
        #titles = titles + [line[2:]]
print(stats)
print(statistics.pstdev(stats))
print(statistics.mean(stats))
print(ratio)
fo.write("%s,\n" % titles)
fo.write("\n-------------------------------------------------------\n")
#fo.write(stats + "\n")
fo.write("%s,\n" % ostats)
fo.write("%s,\n" % stats)
fo.write("-------------------------------------------------------\n")
fo.write("%s,\t"% len(stats))
fo.write("%s,\t"% len(ostats))
fo.write("%s,\n"% len(titles))
fo.write("-------------------------------------------------------\n")
fo.write("%s,\n"% statistics.mean(stats))
fo.write("-------------------------------------------------------\n")
fo.write("%s,\n"% statistics.pstdev(stats))
fo.write("-------------------------------------------------------\n")
fo.write("%s,\n" % ratio)
fo.write("%s,\t\n"% len(ratio))
fo.write("%s,\n"% statistics.mean(ratio))
fo.write("%s,\n"% statistics.pstdev(ratio))
fo.write("-------------------------------------------------------\n")
fp.close()
fo.close()
#data = np.random.randn(1000)
#print(data)
#plt.hist(data)
plt.xlabel('Compression Ratio (Reels)', fontweight="bold")
plt.ylabel('Count', fontweight="bold")
plt.hist(ratio, bins=20)
plt.savefig('histR.jpg')
#for i, line in enumerate(fp):
#    print(enumerate(fp)[4])
#    if i in ind:
#        str=""
#        print(line)
#        # 26th line
#    elif line[0] == 'K':
#        ind = ind + [i]
#fp.close()

#file = open('test3.txt', 'r', encoding='utf-8')
#str1 = file.read()
#file.close()
#print(str1)
#str2 = process(str1)
# Out:
# T: The Ashplant
#
# T: Banshee, The
#
# T: The Bird In The Bush
#
# T: The Blacksmith's
#
# T: The Bloom Of Youth
#
# T: The Boyne Hunt
#
# T: The Boys Of Portaferry
#
# T: Castle Kelly
#
# T: Concertina, The
#
# T: Cooley's
#
# T: The Crock Of Gold
#
# T: The Crooked Road To Dublin
#
# T: Crowley's
#
# T: The Donegal
#
# T: Dowd's No. 9
#
# T: Down The Broom
#
# T: Drag Her Round The Road
#
# T: Dunmore Lasses, The
#
# T: Earl's Chair, The
#
# T: The Eel In The Sink
#
# T: The Fairy Dance
#
# T: Far From Home
#
# T: Father Kelly's
#
# T: Fermoy Lasses, The
#
# T: The Flogging
#
# T: The Galtee Rangers
#
# T: The Galway Rambler
#
# T: George White's Favourite
#
# T: The Gladstone
#
# T: The Glass Of Beer
#
# T: The Green Fields Of Rossbeigh
#
# T: The Hare's Paw
#
# T: The High
#
# T: The Holy Land
#
# T: Humours Of Tulla, The
#
# T: Jenny's Wedding
#
# T: Kitty Goes A-Milking
#
# T: The Lady On The Island
#
# T: The Lansdowne Lass
#
# T: The Longford Collector
#
# T: The Longford Tinker
#
# T: Lucky In Love
#
# T: MacLeod's Farewell
#
# T: Maid Behind The Bar, The
#
# T: Man Of The House, The
#
# T: Merry Blacksmith, The
#
# T: Miss McLeod's
#
# T: Miss Monaghan
#
# T: Molly Bán
#
# T: The Morning Star
#
# T: Mountain Road, The
#
# T: Mulqueeney's
#
# T: Music In The Glen
#
# T: The New Mown Meadows
#
# T: The Old Blackthorn
#
# T: The Old Maids Of Galway
#
# T: Pigeon On The Gate, The
#
# T: Poor But Happy At 53
#
# T: The Pretty Girls Of Mayo
#
# T: The Primrose Lasses
#
# T: The Reconciliation
#
# T: The Reel Of Rio
#
# T: Saint Anne's
#
# T: Sally Gardens, The
#
# T: SG2
#
# T: SG3
#
# T: Ships Are Sailing, The
#
# T: Silver Spear, The
#
# T: Sligo Maid, The
#
# T: Star Of Munster, The
#
# T: Swinging On The Gate
#
# T: Tam Lin
#
# T: Tarbolton, The
#
# T: Tommy Peoples'
#
# T: Toss The Feathers
#
# T: Wind That Shakes The Barley, The
#
# T: Wise Maid, The
#
# T: The Woman Of The House
#
# BE~E2 BAGA|BE~E2 ~G3A|BE~E2 BABd|gedB A2GA|BE~E2 BAGA|BE~E2 ~G3A|~B3A (3Bcd ef|gedB A2GA||B2eB fBeB|~B2ed BAGA|B2eB ~f3d|efdB A2GA|B2eB fBeB|~B2ed BAGA|(3Bcd ef ~g3a|gedB A2GA||
# BE~E2BAGA|BE~E2~G3A|BE~E2BABd|gedBA2GA|BE~E2BAGA|BE~E2~G3A|~B3A(3Bcdef|gedBA2GA||B2eBfBeB|~B2edBAGA|B2eB~f3d|efdBA2GA|B2eBfBeB|~B2edBAGA|(3Bcdef~g3a|gedBA2GA||
# A
# BEEEBAGABEEEGGGABEEEBABdgedBAAGABEEEBAGABEEEGGGABBBABdefgedBAAGABBeBfBeBBBedBAGABBeBfffdefdBAAGABBeBfBeBBBedBAGABdefgggagedBAAGA
# BEEEBAGABEEEGGGABEEEBABdgedBAAGABEEEBAGABEEEGGGABBBABdefgedBAAGABBeBfBeBBBedBAGABBeBfffdefdBAAGABBeBfBeBBBedBAGABdefgggagedBAAGA
# ['B', 'E', [1, 2], 'B', 'A', 'G', 'A', [0, 4], 'G', [12, 2], [7, 5], [4, 2], 'B', 'd', 'g', 'e', 'd', [4, 2], [5, 7], [4, 13], [48, 2], [21, 3], 'e', 'f', [24, 9], 'B', 'e', 'B', 'f', [65, 3], [64, 3], [26, 3], [62, 7], [84, 2], [53, 3], [58, 23], [53, 4], [116, 2], 'a', [24, 8]]
# ['B', 'E', 'EE', 'B', 'A', 'G', 'A', 'BEEE', 'G', 'GG', 'ABEEE', 'BA', 'B', 'd', 'g', 'e', 'd', 'BA', 'AGABEEE', 'BAGABEEEGGGAB', 'BB', 'ABd', 'e', 'f', 'gedBAAGAB', 'B', 'e', 'B', 'f', 'BeB', 'BBe', 'dBA', 'GABBeBf', 'ff', 'def', 'dBAAGABBeBfBeBBBedBAGAB', 'defg', 'gg', 'a', 'gedBAAGA']
# BEEEBAGABEEEGGGABEEEBABdgedBAAGABEEEBAGABEEEGGGABBBABdefgedBAAGABBeBfBeBBBedBAGABBeBfffdefdBAAGABBeBfBeBBBedBAGABdefgggagedBAAGA
# [['B', 'E', [1, 2], 'B', 'A', 'G', 'A', [0, 4], 'G', [12, 2], [7, 5], [4, 2], 'B', 'd', 'g', 'e', 'd', [4, 2], [5, 7], [4, 13], [48, 2], [21, 3], 'e', 'f', [24, 9], 'B', 'e', 'B', 'f', [65, 3], [64, 3], [26, 3], [62, 7], [84, 2], [53, 3], [58, 23], [53, 4], [116, 2], 'a', [24, 8]], ['B', 'E', 'EE', 'B', 'A', 'G', 'A', 'BEEE', 'G', 'GG', 'ABEEE', 'BA', 'B', 'd', 'g', 'e', 'd', 'BA', 'AGABEEE', 'BAGABEEEGGGAB', 'BB', 'ABd', 'e', 'f', 'gedBAAGAB', 'B', 'e', 'B', 'f', 'BeB', 'BBe', 'dBA', 'GABBeBf', 'ff', 'def', 'dBAAGABBeBfBeBBBedBAGAB', 'defg', 'gg', 'a', 'gedBAAGA'], 'BEEEBAGABEEEGGGABEEEBABdgedBAAGABEEEBAGABEEEGGGABBBABdefgedBAAGABBeBfBeBBBedBAGABBeBfffdefdBAAGABBeBfBeBBBedBAGABdefgggagedBAAGA']
# 40 40 128
# |:G2 GD EDEG|AGAB d2 Bd|eged BAGA|BAGE EDDE|G2 GD EDEG|AGAB d2 Bd|eged BAGA|BAGE ED D2:||:ea a2 efgf|eBBA B2 Bd|eB B2 efgf|eBBA B2 Bd|ea a2 efgf|eBBA B2 Bd|eged BAGA|BAGE EDD2:|
# |:G2GDEDEG|AGABd2Bd|egedBAGA|BAGEEDDE|G2GDEDEG|AGABd2Bd|egedBAGA|BAGEEDD2:||:eaa2efgf|eBBAB2Bd|eBB2efgf|eBBAB2Bd|eaa2efgf|eBBAB2Bd|egedBAGA|BAGEEDD2:|
# 2
# GGGDEDEGAGABddBdegedBAGABAGEEDDEGGGDEDEGAGABddBdegedBAGABAGEEDDDeaaaefgfeBBABBBdeBBBefgfeBBABBBdeaaaefgfeBBABBBdegedBAGABAGEEDDD
# GGGDEDEGAGABddBdegedBAGABAGEEDDEGGGDEDEGAGABddBdegedBAGABAGEEDDDeaaaefgfeBBABBBdeBBBefgfeBBABBBdeaaaefgfeBBABBBdegedBAGABAGEEDDD
# ['G', [0, 2], 'D', 'E', [3, 2], 'G', 'A', [7, 2], 'B', 'd', 'd', [11, 2], 'e', 'g', 'e', [13, 2], [8, 4], [8, 2], 'E', [4, 2], [5, 3], [1, 30], 'D', 'e', 'a', [65, 2], 'e', 'f', 'g', 'f', 'e', 'B', [20, 2], [73, 2], [14, 3], [76, 3], [68, 13], [65, 16], [49, 15]]
# ['G', 'GG', 'D', 'E', 'DE', 'G', 'A', 'GA', 'B', 'd', 'd', 'Bd', 'e', 'g', 'e', 'dB', 'AGAB', 'AG', 'E', 'ED', 'DEG', 'GGDEDEGAGABddBdegedBAGABAGEEDD', 'D', 'e', 'a', 'aa', 'e', 'f', 'g', 'f', 'e', 'B', 'BA', 'BB', 'Bde', 'BBB', 'efgfeBBABBBde', 'aaaefgfeBBABBBde', 'gedBAGABAGEEDDD']
# GGGDEDEGAGABddBdegedBAGABAGEEDDEGGGDEDEGAGABddBdegedBAGABAGEEDDDeaaaefgfeBBABBBdeBBBefgfeBBABBBdeaaaefgfeBBABBBdegedBAGABAGEEDDD
# [['G', [0, 2], 'D', 'E', [3, 2], 'G', 'A', [7, 2], 'B', 'd', 'd', [11, 2], 'e', 'g', 'e', [13, 2], [8, 4], [8, 2], 'E', [4, 2], [5, 3], [1, 30], 'D', 'e', 'a', [65, 2], 'e', 'f', 'g', 'f', 'e', 'B', [20, 2], [73, 2], [14, 3], [76, 3], [68, 13], [65, 16], [49, 15]], ['G', 'GG', 'D', 'E', 'DE', 'G', 'A', 'GA', 'B', 'd', 'd', 'Bd', 'e', 'g', 'e', 'dB', 'AGAB', 'AG', 'E', 'ED', 'DEG', 'GGDEDEGAGABddBdegedBAGABAGEEDD', 'D', 'e', 'a', 'aa', 'e', 'f', 'g', 'f', 'e', 'B', 'BA', 'BB', 'Bde', 'BBB', 'efgfeBBABBBde', 'aaaefgfeBBABBBde', 'gedBAGABAGEEDDD'], 'GGGDEDEGAGABddBdegedBAGABAGEEDDEGGGDEDEGAGABddBdegedBAGABAGEEDDDeaaaefgfeBBABBBdeBBBefgfeBBABBBdeaaaefgfeBBABBBdegedBAGABAGEEDDD']
# 39 39 128
# |:d2eB dB~B2|dBAB G2AG|EA~A2 BGGA|BG (3Bde g2ge|d2eB dB~B2|dBAB ~G3E|DEGA B2Bc|dBAc BG~G2:||:(3Bcd ef g2fg|afdf gfed|Bdef ~g3b|agab ~g3a|bg~g2 agef|~g3e dB~B2|DEGA B2Bc|dBAc BG~G2:|
# |:d2eBdB~B2|dBABG2AG|EA~A2BGGA|BG(3Bdeg2ge|d2eBdB~B2|dBAB~G3E|DEGAB2Bc|dBAcBG~G2:||:(3Bcdefg2fg|afdfgfed|Bdef~g3b|agab~g3a|bg~g2agef|~g3edB~B2|DEGAB2Bc|dBAcBG~G2:|
# 2
# ddeBdBBBdBABGGAGEAAABGGABGBegggeddeBdBBBdBABGGGEDEGABBBcdBAcBGGGBdefggfgafdfgfedBdefgggbagabgggabgggagefgggedBBBDEGABBBcdBAcBGGG
# ddeBdBBBdBABGGAGEAAABGGABGBegggeddeBdBBBdBABGGGEDEGABBBcdBAcBGGGBdefggfgafdfgfedBdefgggbagabgggabgggagefgggedBBBDEGABBBcdBAcBGGG
# ['d', 'd', 'e', 'B', 'd', 'B', [5, 2], [4, 2], 'A', 'B', 'G', 'G', 'A', 'G', 'E', 'A', [17, 2], [11, 4], [11, 2], 'B', 'e', 'g', [28, 2], 'e', [0, 14], [15, 2], 'D', 'E', [22, 3], [5, 2], 'c', [8, 3], 'c', [43, 4], [3, 2], 'e', 'f', [28, 2], [67, 2], 'a', 'f', 'd', [67, 2], 'f', [31, 2], [64, 6], 'g', 'b', 'a', [71, 2], 'b', [28, 3], [90, 6], [30, 2], [83, 4], [78, 3], [5, 2], [48, 16]]
# ['d', 'd', 'e', 'B', 'd', 'B', 'BB', 'dB', 'A', 'B', 'G', 'G', 'A', 'G', 'E', 'A', 'AA', 'BGGA', 'BG', 'B', 'e', 'g', 'gg', 'e', 'ddeBdBBBdBABGG', 'GE', 'D', 'E', 'GAB', 'BB', 'c', 'dBA', 'c', 'BGGG', 'Bd', 'e', 'f', 'gg', 'fg', 'a', 'f', 'd', 'fg', 'f', 'ed', 'Bdefgg', 'g', 'b', 'a', 'ga', 'b', 'ggg', 'abggga', 'ge', 'fggg', 'edB', 'BB', 'DEGABBBcdBAcBGGG']
# ddeBdBBBdBABGGAGEAAABGGABGBegggeddeBdBBBdBABGGGEDEGABBBcdBAcBGGGBdefggfgafdfgfedBdefgggbagabgggabgggagefgggedBBBDEGABBBcdBAcBGGG
# [['d', 'd', 'e', 'B', 'd', 'B', [5, 2], [4, 2], 'A', 'B', 'G', 'G', 'A', 'G', 'E', 'A', [17, 2], [11, 4], [11, 2], 'B', 'e', 'g', [28, 2], 'e', [0, 14], [15, 2], 'D', 'E', [22, 3], [5, 2], 'c', [8, 3], 'c', [43, 4], [3, 2], 'e', 'f', [28, 2], [67, 2], 'a', 'f', 'd', [67, 2], 'f', [31, 2], [64, 6], 'g', 'b', 'a', [71, 2], 'b', [28, 3], [90, 6], [30, 2], [83, 4], [78, 3], [5, 2], [48, 16]], ['d', 'd', 'e', 'B', 'd', 'B', 'BB', 'dB', 'A', 'B', 'G', 'G', 'A', 'G', 'E', 'A', 'AA', 'BGGA', 'BG', 'B', 'e', 'g', 'gg', 'e', 'ddeBdBBBdBABGG', 'GE', 'D', 'E', 'GAB', 'BB', 'c', 'dBA', 'c', 'BGGG', 'Bd', 'e', 'f', 'gg', 'fg', 'a', 'f', 'd', 'fg', 'f', 'ed', 'Bdefgg', 'g', 'b', 'a', 'ga', 'b', 'ggg', 'abggga', 'ge', 'fggg', 'edB', 'BB', 'DEGABBBcdBAcBGGG'], 'ddeBdBBBdBABGGAGEAAABGGABGBegggeddeBdBBBdBABGGGEDEGABBBcdBAcBGGGBdefggfgafdfgfedBdefgggbagabgggabgggagefgggedBBBDEGABBBcdBAcBGGG']
# 58 58 128
# G2 GG DGBG|G2 Bd cAFA|G2 GG DGBG|AFDF ABcA|Gz G2 DGBG|G2 Bd cAFA|d2 cA BGAF|DEED Acdc:|d2 B2 dBGB|dB B2 deed|dB B2 dBGB|AFDF ABcA|d2 B2 dBGB|dB B2 deed|d2 cA BGAF|DEED ABcA:|
# G2GGDGBG|G2BdcAFA|G2GGDGBG|AFDFABcA|GzG2DGBG|G2BdcAFA|d2cABGAF|DEEDAcdc:|d2B2dBGB|dBB2deed|dBB2dBGB|AFDFABcA|d2B2dBGB|dBB2deed|d2cABGAF|DEEDABcA:|
# A
# GGGGDGBGGGBdcAFAGGGGDGBGAFDFABcAGzGGDGBGGGBdcAFAddcABGAFDEEDAcdcddBBdBGBdBBBdeeddBBBdBGBAFDFABcAddBBdBGBdBBBdeedddcABGAFDEEDABcA
# GGGGDGBGGGBdcAFAGGGGDGBGAFDFABcAGzGGDGBGGGBdcAFAddcABGAFDEEDAcdcddBBdBGBdBBBdeeddBBBdBGBAFDFABcAddBBdBGBdBBBdeedddcABGAFDEEDABcA
# ['G', [0, 3], 'D', 'G', 'B', [0, 3], 'B', 'd', 'c', 'A', 'F', 'A', [0, 8], [13, 2], 'D', [14, 2], 'B', [12, 2], 'G', 'z', [2, 14], 'd', [11, 3], [22, 5], 'E', 'E', 'D', 'A', 'c', [11, 2], [48, 2], 'B', [10, 2], [6, 2], [67, 3], [66, 3], 'e', 'e', [64, 4], [67, 5], [24, 8], [64, 17], [49, 12], [29, 3]]
# ['G', 'GGG', 'D', 'G', 'B', 'GGG', 'B', 'd', 'c', 'A', 'F', 'A', 'GGGGDGBG', 'AF', 'D', 'FA', 'B', 'cA', 'G', 'z', 'GGDGBGGGBdcAFA', 'd', 'dcA', 'BGAFD', 'E', 'E', 'D', 'A', 'c', 'dc', 'dd', 'B', 'Bd', 'BG', 'BdB', 'BBd', 'e', 'e', 'ddBB', 'BdBGB', 'AFDFABcA', 'ddBBdBGBdBBBdeedd', 'dcABGAFDEEDA', 'BcA']
# GGGGDGBGGGBdcAFAGGGGDGBGAFDFABcAGzGGDGBGGGBdcAFAddcABGAFDEEDAcdcddBBdBGBdBBBdeeddBBBdBGBAFDFABcAddBBdBGBdBBBdeedddcABGAFDEEDABcA
# [['G', [0, 3], 'D', 'G', 'B', [0, 3], 'B', 'd', 'c', 'A', 'F', 'A', [0, 8], [13, 2], 'D', [14, 2], 'B', [12, 2], 'G', 'z', [2, 14], 'd', [11, 3], [22, 5], 'E', 'E', 'D', 'A', 'c', [11, 2], [48, 2], 'B', [10, 2], [6, 2], [67, 3], [66, 3], 'e', 'e', [64, 4], [67, 5], [24, 8], [64, 17], [49, 12], [29, 3]], ['G', 'GGG', 'D', 'G', 'B', 'GGG', 'B', 'd', 'c', 'A', 'F', 'A', 'GGGGDGBG', 'AF', 'D', 'FA', 'B', 'cA', 'G', 'z', 'GGDGBGGGBdcAFA', 'd', 'dcA', 'BGAFD', 'E', 'E', 'D', 'A', 'c', 'dc', 'dd', 'B', 'Bd', 'BG', 'BdB', 'BBd', 'e', 'e', 'ddBB', 'BdBGB', 'AFDFABcA', 'ddBBdBGBdBBBdeedd', 'dcABGAFDEEDA', 'BcA'], 'GGGGDGBGGGBdcAFAGGGGDGBGAFDFABcAGzGGDGBGGGBdcAFAddcABGAFDEEDAcdcddBBdBGBdBBBdeeddBBBdBGBAFDFABcAddBBdBGBdBBBdeedddcABGAFDEEDABcA']
# 44 44 128
# G2 DG EGDF|G2 BG AGEF|G2 DG EGBc|dBcA BGAF|G2 DG EGDF|G2 BG AGEF|G2 DG EGBc|dBAc BG G2:||:gd (3ddd edcA|BdAc BE (3EEE|gd (3ddd edcA|dcAc BG G2|gd (3ddd edcA|BdAc BE E2|cBcd efge|dBAc BG G2:|
# G2DGEGDF|G2BGAGEF|G2DGEGBc|dBcABGAF|G2DGEGDF|G2BGAGEF|G2DGEGBc|dBAcBGG2:||:gd(3dddedcA|BdAcBE(3EEE|gd(3dddedcA|dcAcBGG2|gd(3dddedcA|BdAcBEE2|cBcdefge|dBAcBGG2:|
# 2
# GGDGEGDFGGBGAGEFGGDGEGBcdBcABGAFGGDGEGDFGGBGAGEFGGDGEGBcdBAcBGGGgdddedcABdAcBEEEgdddedcAdcAcBGGGgdddedcABdAcBEEEcBcdefgedBAcBGGG
# GGDGEGDFGGBGAGEFGGDGEGBcdBcABGAFGGDGEGDFGGBGAGEFGGDGEGBcdBAcBGGGgdddedcABdAcBEEEgdddedcAdcAcBGGGgdddedcABdAcBEEEcBcdefgedBAcBGGG
# ['G', 'G', 'D', 'G', 'E', [1, 2], 'F', [0, 2], 'B', 'G', 'A', [3, 2], [7, 3], [2, 4], 'B', 'c', 'd', [22, 2], 'A', [10, 3], [15, 7], [6, 20], 'A', 'c', [10, 2], [0, 2], 'g', 'd', [65, 2], 'e', 'd', [26, 3], 'd', [58, 3], 'E', [77, 2], [64, 8], [69, 3], [59, 21], [59, 2], [23, 2], 'e', 'f', 'g', [68, 2], [57, 7]]
# ['G', 'G', 'D', 'G', 'E', 'GD', 'F', 'GG', 'B', 'G', 'A', 'GE', 'FGG', 'DGEG', 'B', 'c', 'd', 'Bc', 'A', 'BGA', 'FGGDGEG', 'DFGGBGAGEFGGDGEGBcdB', 'A', 'c', 'BG', 'GG', 'g', 'd', 'dd', 'e', 'd', 'cAB', 'd', 'AcB', 'E', 'EE', 'gdddedcA', 'dcA', 'cBGGGgdddedcABdAcBEEE', 'cB', 'cd', 'e', 'f', 'g', 'ed', 'BAcBGGG']
# GGDGEGDFGGBGAGEFGGDGEGBcdBcABGAFGGDGEGDFGGBGAGEFGGDGEGBcdBAcBGGGgdddedcABdAcBEEEgdddedcAdcAcBGGGgdddedcABdAcBEEEcBcdefgedBAcBGGG
# [['G', 'G', 'D', 'G', 'E', [1, 2], 'F', [0, 2], 'B', 'G', 'A', [3, 2], [7, 3], [2, 4], 'B', 'c', 'd', [22, 2], 'A', [10, 3], [15, 7], [6, 20], 'A', 'c', [10, 2], [0, 2], 'g', 'd', [65, 2], 'e', 'd', [26, 3], 'd', [58, 3], 'E', [77, 2], [64, 8], [69, 3], [59, 21], [59, 2], [23, 2], 'e', 'f', 'g', [68, 2], [57, 7]], ['G', 'G', 'D', 'G', 'E', 'GD', 'F', 'GG', 'B', 'G', 'A', 'GE', 'FGG', 'DGEG', 'B', 'c', 'd', 'Bc', 'A', 'BGA', 'FGGDGEG', 'DFGGBGAGEFGGDGEGBcdB', 'A', 'c', 'BG', 'GG', 'g', 'd', 'dd', 'e', 'd', 'cAB', 'd', 'AcB', 'E', 'EE', 'gdddedcA', 'dcA', 'cBGGGgdddedcABdAcBEEE', 'cB', 'cd', 'e', 'f', 'g', 'ed', 'BAcBGGG'], 'GGDGEGDFGGBGAGEFGGDGEGBcdBcABGAFGGDGEGDFGGBGAGEFGGDGEGBcdBAcBGGGgdddedcABdAcBEEEgdddedcAdcAcBGGGgdddedcABdAcBEEEcBcdefgedBAcBGGG']
# 46 46 128
# BAFA DAFA|DAFA BE~E2|BAFA DAFA|ABde fedB|BAFA DAFA|DAFA BE~E2|BAFA DAFA|ABde fdd2||faaf afdf|gfga be~e2|faaf afdB|ABde fdd2|faaf afdf|gfga be~e2|fgfe d2dB|ABde fedB||
# BAFADAFA|DAFABE~E2|BAFADAFA|ABdefedB|BAFADAFA|DAFABE~E2|BAFADAFA|ABdefdd2||faafafdf|gfgabe~e2|faafafdB|ABdefdd2|faafafdf|gfgabe~e2|fgfed2dB|ABdefedB||
# B
# BAFADAFADAFABEEEBAFADAFAABdefedBBAFADAFADAFABEEEBAFADAFAABdefdddfaafafdfgfgabeeefaafafdBABdefdddfaafafdfgfgabeeefgfedddBABdefedB
# BAFADAFADAFABEEEBAFADAFAABdefedBBAFADAFADAFABEEEBAFADAFAABdefdddfaafafdfgfgabeeefaafafdBABdefdddfaafafdfgfgabeeefgfedddBABdefedB
# ['B', 'A', 'F', 'A', 'D', [1, 7], 'B', 'E', [13, 2], [0, 8], [11, 2], 'd', 'e', 'f', 'e', 'd', 'B', [0, 29], 'd', [61, 2], 'f', 'a', 'a', [64, 2], [60, 2], 'f', 'g', [71, 2], 'a', 'b', 'e', [77, 2], [64, 7], [0, 2], [57, 24], [72, 2], [29, 2], [61, 2], [87, 6], [29, 3]]
# ['B', 'A', 'F', 'A', 'D', 'AFADAFA', 'B', 'E', 'EE', 'BAFADAFA', 'AB', 'd', 'e', 'f', 'e', 'd', 'B', 'BAFADAFADAFABEEEBAFADAFAABdef', 'd', 'dd', 'f', 'a', 'a', 'fa', 'fd', 'f', 'g', 'fg', 'a', 'b', 'e', 'ee', 'faafafd', 'BA', 'Bdefdddfaafafdfgfgabeeef', 'gf', 'ed', 'dd', 'BABdef', 'edB']
# BAFADAFADAFABEEEBAFADAFAABdefedBBAFADAFADAFABEEEBAFADAFAABdefdddfaafafdfgfgabeeefaafafdBABdefdddfaafafdfgfgabeeefgfedddBABdefedB
# [['B', 'A', 'F', 'A', 'D', [1, 7], 'B', 'E', [13, 2], [0, 8], [11, 2], 'd', 'e', 'f', 'e', 'd', 'B', [0, 29], 'd', [61, 2], 'f', 'a', 'a', [64, 2], [60, 2], 'f', 'g', [71, 2], 'a', 'b', 'e', [77, 2], [64, 7], [0, 2], [57, 24], [72, 2], [29, 2], [61, 2], [87, 6], [29, 3]], ['B', 'A', 'F', 'A', 'D', 'AFADAFA', 'B', 'E', 'EE', 'BAFADAFA', 'AB', 'd', 'e', 'f', 'e', 'd', 'B', 'BAFADAFADAFABEEEBAFADAFAABdef', 'd', 'dd', 'f', 'a', 'a', 'fa', 'fd', 'f', 'g', 'fg', 'a', 'b', 'e', 'ee', 'faafafd', 'BA', 'Bdefdddfaafafdfgfgabeeef', 'gf', 'ed', 'dd', 'BABdef', 'edB'], 'BAFADAFADAFABEEEBAFADAFAABdefedBBAFADAFADAFABEEEBAFADAFAABdefdddfaafafdfgfgabeeefaafafdBABdefdddfaafafdfgfgabeeefgfedddBABdefedB']
# 40 40 128
# |:G2 BG Ac BA|G2AG GE DE|G2 BG AB cd|dB GB Ac BA|G2 BG Ac BA|G2AG GE DE|G2 BG AB cd|dB AB G3 A|(3Bcd gd ed gd|Bd gd eg dc|Bd gd ed ef|ge dB cA BA|(3Bcd gd ed gd|Bd gd eg dc|Bd gd ed ef|ge dB cA BA:|
# |:G2BGAcBA|G2AGGEDE|G2BGABcd|dBGBAcBA|G2BGAcBA|G2AGGEDE|G2BGABcd|dBABG3A|(3Bcdgdedgd|Bdgdegdc|Bdgdedef|gedBcABA|(3Bcdgdedgd|Bdgdegdc|Bdgdedef|gedBcABA:|
# A
# GGBGAcBAGGAGGEDEGGBGABcddBGBAcBAGGBGAcBAGGAGGEDEGGBGABcddBABGGGABdgdedgdBdgdegdcBdgdedefgedBcABABdgdedgdBdgdegdcBdgdedefgedBcABA
# GGBGAcBAGGAGGEDEGGBGABcddBGBAcBAGGBGAcBAGGAGGEDEGGBGABcddBABGGGABdgdedgdBdgdegdcBdgdedefgedBcABABdgdedgdBdgdegdcBdgdedefgedBcABA
# ['G', 'G', 'B', 'G', 'A', 'c', 'B', 'A', [0, 2], [7, 3], 'E', 'D', 'E', [0, 5], 'B', 'c', 'd', 'd', [2, 2], [6, 2], [5, 5], [2, 24], [20, 2], [0, 2], [19, 3], 'd', 'g', 'd', 'e', [65, 3], [64, 5], [66, 2], [5, 2], [65, 5], 'e', 'f', 'g', [68, 2], [21, 2], [20, 2], [63, 33]]
# ['G', 'G', 'B', 'G', 'A', 'c', 'B', 'A', 'GG', 'AGG', 'E', 'D', 'E', 'GGBGA', 'B', 'c', 'd', 'd', 'BG', 'BA', 'cBAGG', 'BGAcBAGGAGGEDEGGBGABcddB', 'AB', 'GG', 'GAB', 'd', 'g', 'd', 'e', 'dgd', 'Bdgde', 'gd', 'cB', 'dgded', 'e', 'f', 'g', 'ed', 'Bc', 'AB', 'ABdgdedgdBdgdegdcBdgdedefgedBcABA']
# GGBGAcBAGGAGGEDEGGBGABcddBGBAcBAGGBGAcBAGGAGGEDEGGBGABcddBABGGGABdgdedgdBdgdegdcBdgdedefgedBcABABdgdedgdBdgdegdcBdgdedefgedBcABA
# [['G', 'G', 'B', 'G', 'A', 'c', 'B', 'A', [0, 2], [7, 3], 'E', 'D', 'E', [0, 5], 'B', 'c', 'd', 'd', [2, 2], [6, 2], [5, 5], [2, 24], [20, 2], [0, 2], [19, 3], 'd', 'g', 'd', 'e', [65, 3], [64, 5], [66, 2], [5, 2], [65, 5], 'e', 'f', 'g', [68, 2], [21, 2], [20, 2], [63, 33]], ['G', 'G', 'B', 'G', 'A', 'c', 'B', 'A', 'GG', 'AGG', 'E', 'D', 'E', 'GGBGA', 'B', 'c', 'd', 'd', 'BG', 'BA', 'cBAGG', 'BGAcBAGGAGGEDEGGBGABcddB', 'AB', 'GG', 'GAB', 'd', 'g', 'd', 'e', 'dgd', 'Bdgde', 'gd', 'cB', 'dgded', 'e', 'f', 'g', 'ed', 'Bc', 'AB', 'ABdgdedgdBdgdegdcBdgdedefgedBcABA'], 'GGBGAcBAGGAGGEDEGGBGABcddBGBAcBAGGBGAcBAGGAGGEDEGGBGABcddBABGGGABdgdedgdBdgdegdcBdgdedefgedBcABABdgdedgdBdgdegdcBdgdedefgedBcABA']
# 41 41 128
# A2 cA ~A2 cA|GE ~E2 G2 EG|A2 cA GAcd|(3efg dB BAdB|A2 cA ~A2 cA|GBEF G2 EG|A2 cA GAcd|egdB BA ~A2|age^c ~d2 ef|cAGE ~G2 G2|age^c ~d2 cd|eaag a2 bg|age^c ~d2 ef|cAGE G2 EG|A2 cA GAcd|egdB BA ~A2|
# A2cA~A2cA|GE~E2G2EG|A2cAGAcd|(3efgdBBAdB|A2cA~A2cA|GBEFG2EG|A2cAGAcd|egdBBA~A2|age^c~d2ef|cAGE~G2G2|age^c~d2cd|eaaga2bg|age^c~d2ef|cAGEG2EG|A2cAGAcd|egdBBA~A2|
# 2
# AAcAAAcAGEEEGGEGAAcAGAcdegdBBAdBAAcAAAcAGBEFGGEGAAcAGAcdegdBBAAAage^cddefcAGEGGGGage^cddcdeaagaabgage^cddefcAGEGGEGAAcAGAcdegdBBAAA
# AAcAAAcAGEEEGGEGAAcAGAcdegdBBAdBAAcAAAcAGBEFGGEGAAcAGAcdegdBBAAAage^cddefcAGEGGGGage^cddcdeaagaabgage^cddefcAGEGGEGAAcAGAcdegdBBAAA
# ['A', 'A', 'c', [0, 2], [1, 3], 'G', 'E', [9, 2], 'G', [8, 2], 'G', [4, 5], [1, 2], 'd', 'e', 'g', 'd', 'B', 'B', 'A', [26, 2], [0, 9], 'B', 'E', 'F', [12, 18], [0, 2], 'a', 'g', 'e', '^', [22, 2], [23, 2], 'f', [6, 4], [12, 2], [12, 2], [64, 7], [22, 3], 'a', [64, 2], [91, 2], 'b', [93, 2], [65, 14], [46, 18]]
# ['A', 'A', 'c', 'AA', 'AcA', 'G', 'E', 'EE', 'G', 'GE', 'G', 'AAcAG', 'Ac', 'd', 'e', 'g', 'd', 'B', 'B', 'A', 'dB', 'AAcAAAcAG', 'B', 'E', 'F', 'GGEGAAcAGAcdegdBBA', 'AA', 'a', 'g', 'e', '^', 'cd', 'de', 'f', 'cAGE', 'GG', 'GG', 'age^cdd', 'cde', 'a', 'ag', 'aa', 'b', 'ga', 'ge^cddefcAGEGG', 'EGAAcAGAcdegdBBAAA']
# AAcAAAcAGEEEGGEGAAcAGAcdegdBBAdBAAcAAAcAGBEFGGEGAAcAGAcdegdBBAAAage^cddefcAGEGGGGage^cddcdeaagaabgage^cddefcAGEGGEGAAcAGAcdegdBBAAA
# [['A', 'A', 'c', [0, 2], [1, 3], 'G', 'E', [9, 2], 'G', [8, 2], 'G', [4, 5], [1, 2], 'd', 'e', 'g', 'd', 'B', 'B', 'A', [26, 2], [0, 9], 'B', 'E', 'F', [12, 18], [0, 2], 'a', 'g', 'e', '^', [22, 2], [23, 2], 'f', [6, 4], [12, 2], [12, 2], [64, 7], [22, 3], 'a', [64, 2], [91, 2], 'b', [93, 2], [65, 14], [46, 18]], ['A', 'A', 'c', 'AA', 'AcA', 'G', 'E', 'EE', 'G', 'GE', 'G', 'AAcAG', 'Ac', 'd', 'e', 'g', 'd', 'B', 'B', 'A', 'dB', 'AAcAAAcAG', 'B', 'E', 'F', 'GGEGAAcAGAcdegdBBA', 'AA', 'a', 'g', 'e', '^', 'cd', 'de', 'f', 'cAGE', 'GG', 'GG', 'age^cdd', 'cde', 'a', 'ag', 'aa', 'b', 'ga', 'ge^cddefcAGEGG', 'EGAAcAGAcdegdBBAAA'], 'AAcAAAcAGEEEGGEGAAcAGAcdegdBBAdBAAcAAAcAGBEFGGEGAAcAGAcdegdBBAAAage^cddefcAGEGGGGage^cddcdeaagaabgage^cddefcAGEGGEGAAcAGAcdegdBBAAA']
# 46 46 131
# |:A2FA BAFA|A2FA BAFA|B2BA B2BA|B2BA BAFA|A2FA BAFA|A2FA BAFA|FABc d2dA|BAFE D4:||:Addd Addd|AddA BAFA|B2BA B2BA|B2BA BAFA|Addd Addd|AddA BAFA|FABc d2dA|BAFE D4:|
# |:A2FABAFA|A2FABAFA|B2BAB2BA|B2BABAFA|A2FABAFA|A2FABAFA|FABcd2dA|BAFED4:||:AdddAddd|AddABAFA|B2BAB2BA|B2BABAFA|AdddAddd|AddABAFA|FABcd2dA|BAFED4:|
# 4
# AAFABAFAAAFABAFABBBABBBABBBABAFAAAFABAFAAAFABAFAFABcdddABAFEDDDDAdddAdddAddABAFABBBABBBABBBABAFAAdddAdddAddABAFAFABcdddABAFEDDDD
# AAFABAFAAAFABAFABBBABBBABBBABAFAAAFABAFAAAFABAFAFABcdddABAFEDDDDAdddAdddAddABAFABBBABBBABBBABAFAAdddAdddAddABAFAFABcdddABAFEDDDD
# ['A', 'A', 'F', 'A', 'B', [1, 3], [0, 8], 'B', [16, 2], [15, 10], [5, 11], [0, 8], [2, 3], 'c', 'd', [52, 2], [3, 4], 'E', 'D', [60, 3], 'A', [52, 4], [65, 6], [11, 22], [65, 15], [48, 16]]
# ['A', 'A', 'F', 'A', 'B', 'AFA', 'AAFABAFA', 'B', 'BB', 'ABBBABBBAB', 'AFAAAFABAFA', 'AAFABAFA', 'FAB', 'c', 'd', 'dd', 'ABAF', 'E', 'D', 'DDD', 'A', 'dddA', 'dddAdd', 'ABAFABBBABBBABBBABAFAA', 'dddAdddAddABAFA', 'FABcdddABAFEDDDD']
# AAFABAFAAAFABAFABBBABBBABBBABAFAAAFABAFAAAFABAFAFABcdddABAFEDDDDAdddAdddAddABAFABBBABBBABBBABAFAAdddAdddAddABAFAFABcdddABAFEDDDD
# [['A', 'A', 'F', 'A', 'B', [1, 3], [0, 8], 'B', [16, 2], [15, 10], [5, 11], [0, 8], [2, 3], 'c', 'd', [52, 2], [3, 4], 'E', 'D', [60, 3], 'A', [52, 4], [65, 6], [11, 22], [65, 15], [48, 16]], ['A', 'A', 'F', 'A', 'B', 'AFA', 'AAFABAFA', 'B', 'BB', 'ABBBABBBAB', 'AFAAAFABAFA', 'AAFABAFA', 'FAB', 'c', 'd', 'dd', 'ABAF', 'E', 'D', 'DDD', 'A', 'dddA', 'dddAdd', 'ABAFABBBABBBABBBABAFAA', 'dddAdddAddABAFA', 'FABcdddABAFEDDDD'], 'AAFABAFAAAFABAFABBBABBBABBBABAFAAAFABAFAAAFABAFAFABcdddABAFEDDDDAdddAdddAddABAFABBBABBBABBBABAFAAdddAdddAddABAFAFABcdddABAFEDDDD']
# 26 26 128
# |:EBBA B2 EB|B2 AB dBAG|FDAD BDAD|FDAD dAFD|EBBA B2 EB|B2 AB defg|afec dBAF|DEFD E2:||:gf|eB B2 efge|eB B2 gedB|A2 FA DAFA|A2 FA defg|eB B2 eBgB|eB B2 defg|afec dBAF|DEFD E4:|
# |:EBBAB2EB|B2ABdBAG|FDADBDAD|FDADdAFD|EBBAB2EB|B2ABdefg|afecdBAF|DEFDE2:||:gf|eBB2efge|eBB2gedB|A2FADAFA|A2FAdefg|eBB2eBgB|eBB2defg|afecdBAF|DEFDE4:|
# 4
# EBBABBEBBBABdBAGFDADBDADFDADdAFDEBBABBEBBBABdefgafecdBAFDEFDEEgfeBBBefgeeBBBgedBAAFADAFAAAFAdefgeBBBeBgBeBBBdefgafecdBAFDEFDEEEE
# EBBABBEBBBABdBAGFDADBDADFDADdAFDEBBABBEBBBABdefgafecdBAFDEFDEEgfeBBBefgeeBBBgedBAAFADAFAAAFAdefgeBBBeBgBeBBBdefgafecdBAFDEFDEEEE
# ['E', 'B', 'B', 'A', [1, 2], [0, 3], [2, 3], 'd', [2, 2], 'G', 'F', 'D', 'A', 'D', 'B', [17, 3], [16, 4], 'd', 'A', [16, 2], [0, 13], 'e', 'f', 'g', 'a', 'f', 'e', 'c', [12, 3], [30, 3], [30, 3], 'E', 'g', [49, 2], [7, 3], [45, 3], 'e', [64, 4], [70, 2], [12, 3], [29, 2], [18, 2], [81, 3], [80, 4], [44, 4], [64, 5], [75, 2], [99, 3], [1, 2], [44, 18], [60, 2]]
# ['E', 'B', 'B', 'A', 'BB', 'EBB', 'BAB', 'd', 'BA', 'G', 'F', 'D', 'A', 'D', 'B', 'DAD', 'FDAD', 'd', 'A', 'FD', 'EBBABBEBBBABd', 'e', 'f', 'g', 'a', 'f', 'e', 'c', 'dBA', 'FDE', 'FDE', 'E', 'g', 'fe', 'BBB', 'efg', 'e', 'eBBB', 'ge', 'dBA', 'AF', 'AD', 'AFA', 'AAFA', 'defg', 'eBBBe', 'Bg', 'BeB', 'BB', 'defgafecdBAFDEFDEE', 'EE']
# EBBABBEBBBABdBAGFDADBDADFDADdAFDEBBABBEBBBABdefgafecdBAFDEFDEEgfeBBBefgeeBBBgedBAAFADAFAAAFAdefgeBBBeBgBeBBBdefgafecdBAFDEFDEEEE
# [['E', 'B', 'B', 'A', [1, 2], [0, 3], [2, 3], 'd', [2, 2], 'G', 'F', 'D', 'A', 'D', 'B', [17, 3], [16, 4], 'd', 'A', [16, 2], [0, 13], 'e', 'f', 'g', 'a', 'f', 'e', 'c', [12, 3], [30, 3], [30, 3], 'E', 'g', [49, 2], [7, 3], [45, 3], 'e', [64, 4], [70, 2], [12, 3], [29, 2], [18, 2], [81, 3], [80, 4], [44, 4], [64, 5], [75, 2], [99, 3], [1, 2], [44, 18], [60, 2]], ['E', 'B', 'B', 'A', 'BB', 'EBB', 'BAB', 'd', 'BA', 'G', 'F', 'D', 'A', 'D', 'B', 'DAD', 'FDAD', 'd', 'A', 'FD', 'EBBABBEBBBABd', 'e', 'f', 'g', 'a', 'f', 'e', 'c', 'dBA', 'FDE', 'FDE', 'E', 'g', 'fe', 'BBB', 'efg', 'e', 'eBBB', 'ge', 'dBA', 'AF', 'AD', 'AFA', 'AAFA', 'defg', 'eBBBe', 'Bg', 'BeB', 'BB', 'defgafecdBAFDEFDEE', 'EE'], 'EBBABBEBBBABdBAGFDADBDADFDADdAFDEBBABBEBBBABdefgafecdBAFDEFDEEgfeBBBefgeeBBBgedBAAFADAFAAAFAdefgeBBBeBgBeBBBdefgafecdBAFDEFDEEEE']
# 51 51 128
# |:B3B BAGE|G3A GEDB|DEGA BAGA|B2dB BAA2|B3B BAGE|G3A GED2|g2fg egdB|DEGA BGG2:||:eaa2 bage|a2ba gede|gedB GABd|egdB BAA2|eaa2 bage|a2ba gede|g2fg egdB|DEGA BGG2:|
# |:B3BBAGE|G3AGEDB|DEGABAGA|B2dBBAA2|B3BBAGE|G3AGED2|g2fgegdB|DEGABGG2:||:eaa2bage|a2bagede|gedBGABd|egdBBAA2|eaa2bage|a2bagede|g2fgegdB|DEGABGG2:|
# 2
# BBBBBAGEGGGAGEDBDEGABAGABBdBBAAABBBBBAGEGGGAGEDDggfgegdBDEGABGGGeaaabageaabagedegedBGABdegdBBAAAeaaabageaabagedeggfgegdBDEGABGGG
# BBBBBAGEGGGAGEDBDEGABAGABBdBBAAABBBBBAGEGGGAGEDDggfgegdBDEGABGGGeaaabageaabagedegedBGABdegdBBAAAeaaabageaabagedeggfgegdBDEGABGGG
# ['B', [0, 4], 'A', 'G', 'E', 'G', [8, 2], [5, 3], 'D', 'B', 'D', [7, 2], 'A', [4, 3], [19, 2], 'B', 'd', [3, 3], [29, 2], [0, 15], 'D', 'g', 'g', 'f', 'g', 'e', 'g', [26, 2], [16, 5], [8, 3], 'e', 'a', [65, 2], 'b', 'a', [51, 2], [66, 6], 'd', [52, 2], [77, 2], [60, 2], [19, 2], [78, 3], [26, 6], [64, 17], [49, 15]]
# ['B', 'BBBB', 'A', 'G', 'E', 'G', 'GG', 'AGE', 'D', 'B', 'D', 'EG', 'A', 'BAG', 'AB', 'B', 'd', 'BBA', 'AA', 'BBBBBAGEGGGAGED', 'D', 'g', 'g', 'f', 'g', 'e', 'g', 'dB', 'DEGAB', 'GGG', 'e', 'a', 'aa', 'b', 'a', 'ge', 'aabage', 'd', 'eg', 'ed', 'BG', 'AB', 'deg', 'dBBAAA', 'eaaabageaabagedeg', 'gfgegdBDEGABGGG']
# BBBBBAGEGGGAGEDBDEGABAGABBdBBAAABBBBBAGEGGGAGEDDggfgegdBDEGABGGGeaaabageaabagedegedBGABdegdBBAAAeaaabageaabagedeggfgegdBDEGABGGG
# [['B', [0, 4], 'A', 'G', 'E', 'G', [8, 2], [5, 3], 'D', 'B', 'D', [7, 2], 'A', [4, 3], [19, 2], 'B', 'd', [3, 3], [29, 2], [0, 15], 'D', 'g', 'g', 'f', 'g', 'e', 'g', [26, 2], [16, 5], [8, 3], 'e', 'a', [65, 2], 'b', 'a', [51, 2], [66, 6], 'd', [52, 2], [77, 2], [60, 2], [19, 2], [78, 3], [26, 6], [64, 17], [49, 15]], ['B', 'BBBB', 'A', 'G', 'E', 'G', 'GG', 'AGE', 'D', 'B', 'D', 'EG', 'A', 'BAG', 'AB', 'B', 'd', 'BBA', 'AA', 'BBBBBAGEGGGAGED', 'D', 'g', 'g', 'f', 'g', 'e', 'g', 'dB', 'DEGAB', 'GGG', 'e', 'a', 'aa', 'b', 'a', 'ge', 'aabage', 'd', 'eg', 'ed', 'BG', 'AB', 'deg', 'dBBAAA', 'eaaabageaabagedeg', 'gfgegdBDEGABGGG'], 'BBBBBAGEGGGAGEDBDEGABAGABBdBBAAABBBBBAGEGGGAGEDDggfgegdBDEGABGGGeaaabageaabagedegedBGABdegdBBAAAeaaabageaabagedeggfgegdBDEGABGGG']
# 46 46 128
# G2 BG FGAF|(3GGG Ac BdcA|GBAG FGAg|fdcA dBcA|GBAG FGAF|GBAc BdcA|GBAG FGAg|fdcA d2 Bc|d~g3 fgaf|d~g3 agfe|d~g3 fgag|fdcA dBcA|d~g3 fgaf|d~g3 afga|bgaf gbag|fdcA BGAF|
# G2BGFGAF|(3GGGAcBdcA|GBAGFGAg|fdcAdBcA|GBAGFGAF|GBAcBdcA|GBAGFGAg|fdcAd2Bc|d~g3fgaf|d~g3agfe|d~g3fgag|fdcAdBcA|d~g3fgaf|d~g3afga|bgafgbag|fdcABGAF|
# F
# GGBGFGAFGGAcBdcAGBAGFGAgfdcAdBcAGBAGFGAFGBAcBdcAGBAGFGAgfdcAddBcdgggfgafdgggagfedgggfgagfdcAdBcAdgggfgafdgggafgabgafgbagfdcABGAF
# GGBGFGAFGGAcBdcAGBAGFGAgfdcAdBcAGBAGFGAFGBAcBdcAGBAGFGAgfdcAddBcdgggfgafdgggagfedgggfgagfdcAdBcAdgggfgafdgggafgabgafgbagfdcABGAF
# ['G', 'G', 'B', 'G', 'F', 'G', 'A', [4, 2], [5, 2], 'c', 'B', 'd', 'c', 'A', [1, 2], [15, 2], [4, 3], 'g', 'f', [13, 3], 'd', 'B', [14, 9], [4, 2], [17, 2], [11, 18], [28, 3], 'd', 'g', [65, 2], 'f', 'g', 'a', [24, 2], [65, 3], 'a', [23, 2], 'e', [64, 7], [23, 9], [64, 13], [68, 3], 'b', [107, 4], 'b', [86, 6], [2, 2], [6, 2]]
# ['G', 'G', 'B', 'G', 'F', 'G', 'A', 'FG', 'GA', 'c', 'B', 'd', 'c', 'A', 'GB', 'AG', 'FGA', 'g', 'f', 'dcA', 'd', 'B', 'cAGBAGFGA', 'FG', 'BA', 'cBdcAGBAGFGAgfdcAd', 'dBc', 'd', 'g', 'gg', 'f', 'g', 'a', 'fd', 'ggg', 'a', 'gf', 'e', 'dgggfga', 'gfdcAdBcA', 'dgggfgafdggga', 'fga', 'b', 'gafg', 'b', 'agfdcA', 'BG', 'AF']
# GGBGFGAFGGAcBdcAGBAGFGAgfdcAdBcAGBAGFGAFGBAcBdcAGBAGFGAgfdcAddBcdgggfgafdgggagfedgggfgagfdcAdBcAdgggfgafdgggafgabgafgbagfdcABGAF
# [['G', 'G', 'B', 'G', 'F', 'G', 'A', [4, 2], [5, 2], 'c', 'B', 'd', 'c', 'A', [1, 2], [15, 2], [4, 3], 'g', 'f', [13, 3], 'd', 'B', [14, 9], [4, 2], [17, 2], [11, 18], [28, 3], 'd', 'g', [65, 2], 'f', 'g', 'a', [24, 2], [65, 3], 'a', [23, 2], 'e', [64, 7], [23, 9], [64, 13], [68, 3], 'b', [107, 4], 'b', [86, 6], [2, 2], [6, 2]], ['G', 'G', 'B', 'G', 'F', 'G', 'A', 'FG', 'GA', 'c', 'B', 'd', 'c', 'A', 'GB', 'AG', 'FGA', 'g', 'f', 'dcA', 'd', 'B', 'cAGBAGFGA', 'FG', 'BA', 'cBdcAGBAGFGAgfdcAd', 'dBc', 'd', 'g', 'gg', 'f', 'g', 'a', 'fd', 'ggg', 'a', 'gf', 'e', 'dgggfga', 'gfdcAdBcA', 'dgggfgafdggga', 'fga', 'b', 'gafg', 'b', 'agfdcA', 'BG', 'AF'], 'GGBGFGAFGGAcBdcAGBAGFGAgfdcAdBcAGBAGFGAFGBAcBdcAGBAGFGAgfdcAddBcdgggfgafdgggagfedgggfgagfdcAdBcAdgggfgafdgggafgabgafgbagfdcABGAF']
# 48 48 128
# A2Ad B2dB|AD (3FED AD (3FED|AddA BABc|dfeg fedB|A2Ad B2dB|AD (3FED AD (3FED|A2Ad BABc|dfeg fdde||f2af g2fg|eA (3cBA eA (3cBA|fefa g2fg|afge fdde|f2af g2fg|eA (3cBA eA (3cBA|fefa gefg|afge fedB||
# A2AdB2dB|AD(3FEDAD(3FED|AddABABc|dfegfedB|A2AdB2dB|AD(3FEDAD(3FED|A2AdBABc|dfegfdde||f2afg2fg|eA(3cBAeA(3cBA|fefag2fg|afgefdde|f2afg2fg|eA(3cBAeA(3cBA|fefagefg|afgefedB||
# B
# AAAdBBdBADFDADFDAddABABcdfegfedBAAAdBBdBADFDADFDAAAdBABcdfegfddeffafggfgeAcAeAcAfefaggfgafgefddeffafggfgeAcAeAcAfefagefgafgefedB
# AAAdBBdBADFDADFDAddABABcdfegfedBAAAdBBdBADFDADFDAAAdBABcdfegfddeffafggfgeAcAeAcAfefaggfgafgefddeffafggfgeAcAeAcAfefagefgafgefedB
# ['A', [0, 2], 'd', 'B', 'B', [3, 2], 'A', 'D', 'F', 'D', [8, 5], 'd', 'd', 'A', [7, 2], 'B', 'c', 'd', 'f', 'e', 'g', [25, 2], [6, 3], [1, 16], [1, 4], [21, 8], [17, 2], 'e', 'f', 'f', 'a', 'f', 'g', [27, 2], 'g', 'e', 'A', 'c', 'A', [72, 4], [25, 2], [65, 2], [68, 4], [66, 3], [63, 2], [61, 24], [63, 2], [87, 6], [29, 3]]
# ['A', 'AA', 'd', 'B', 'B', 'dB', 'A', 'D', 'F', 'D', 'ADFDA', 'd', 'd', 'A', 'BA', 'B', 'c', 'd', 'f', 'e', 'g', 'fe', 'dBA', 'AAdBBdBADFDADFDA', 'AAdB', 'ABcdfegf', 'dd', 'e', 'f', 'f', 'a', 'f', 'g', 'gf', 'g', 'e', 'A', 'c', 'A', 'eAcA', 'fe', 'fa', 'ggfg', 'afg', 'ef', 'ddeffafggfgeAcAeAcAfefag', 'ef', 'gafgef', 'edB']
# AAAdBBdBADFDADFDAddABABcdfegfedBAAAdBBdBADFDADFDAAAdBABcdfegfddeffafggfgeAcAeAcAfefaggfgafgefddeffafggfgeAcAeAcAfefagefgafgefedB
# [['A', [0, 2], 'd', 'B', 'B', [3, 2], 'A', 'D', 'F', 'D', [8, 5], 'd', 'd', 'A', [7, 2], 'B', 'c', 'd', 'f', 'e', 'g', [25, 2], [6, 3], [1, 16], [1, 4], [21, 8], [17, 2], 'e', 'f', 'f', 'a', 'f', 'g', [27, 2], 'g', 'e', 'A', 'c', 'A', [72, 4], [25, 2], [65, 2], [68, 4], [66, 3], [63, 2], [61, 24], [63, 2], [87, 6], [29, 3]], ['A', 'AA', 'd', 'B', 'B', 'dB', 'A', 'D', 'F', 'D', 'ADFDA', 'd', 'd', 'A', 'BA', 'B', 'c', 'd', 'f', 'e', 'g', 'fe', 'dBA', 'AAdBBdBADFDADFDA', 'AAdB', 'ABcdfegf', 'dd', 'e', 'f', 'f', 'a', 'f', 'g', 'gf', 'g', 'e', 'A', 'c', 'A', 'eAcA', 'fe', 'fa', 'ggfg', 'afg', 'ef', 'ddeffafggfgeAcAeAcAfefag', 'ef', 'gafgef', 'edB'], 'AAAdBBdBADFDADFDAddABABcdfegfedBAAAdBBdBADFDADFDAAAdBABcdfegfddeffafggfgeAcAeAcAfefaggfgafgefddeffafggfgeAcAeAcAfefagefgafgefedB']
# 49 49 128
# |D2 DE FEFA|dFAF BFAF|E2 EF GFGA|(3Bcd AF EGFE|D2 DE FEFA|dFAF ABde|(3fga ec dABG|(3FGF EF D4|||defg afdf|afdf a2 (3agf|edef gfed|edef g2 (3gfe|defg afdf|afdf abag|(3fgf (3efe dABG|(3FGF EF D4||
# |D2DEFEFA|dFAFBFAF|E2EFGFGA|(3BcdAFEGFE|D2DEFEFA|dFAFABde|(3fgaecdABG|(3FGFEFD4|||defgafdf|afdfa2(3agf|edefgfed|edefg2(3gfe|defgafdf|afdfabag|(3fgf(3efedABG|(3FGFEFD4||
# 4
# DDDEFEFAdFAFBFAFEEEFGFGABdAFEGFEDDDEFEFAdFAFABdefaecdABGFFEFDDDDdefgafdfafdfaaafedefgfededefgggedefgafdfafdfabagffeedABGFFEFDDDD
# DDDEFEFAdFAFBFAFEEEFGFGABdAFEGFEDDDEFEFAdFAFABdefaecdABGFFEFDDDDdefgafdfafdfaaafedefgfededefgggedefgafdfafdfabagffeedABGFFEFDDDD
# ['D', [0, 2], 'E', 'F', [3, 2], 'A', 'd', [6, 2], 'F', 'B', [9, 3], 'E', [16, 2], 'F', 'G', [19, 2], 'A', 'B', 'd', [14, 3], [20, 2], 'E', [0, 12], [23, 3], 'e', 'f', 'a', 'e', 'c', [25, 2], 'B', [20, 2], [4, 3], [0, 3], 'D', [46, 3], 'g', 'a', 'f', 'd', [48, 2], [69, 4], [76, 2], 'f', 'e', [64, 4], [79, 4], [64, 4], [92, 2], [80, 5], [68, 9], 'b', 'a', [84, 2], [79, 2], [80, 2], [53, 11]]
# ['D', 'DD', 'E', 'F', 'EF', 'A', 'd', 'FA', 'F', 'B', 'FAF', 'E', 'EE', 'F', 'G', 'FG', 'A', 'B', 'd', 'AFE', 'GF', 'E', 'DDDEFEFAdFAF', 'ABd', 'e', 'f', 'a', 'e', 'c', 'dA', 'B', 'GF', 'FEF', 'DDD', 'D', 'def', 'g', 'a', 'f', 'd', 'fa', 'fdfa', 'aa', 'f', 'e', 'defg', 'fede', 'defg', 'gg', 'edefg', 'afdfafdfa', 'b', 'a', 'gf', 'fe', 'ed', 'ABGFFEFDDDD']
# DDDEFEFAdFAFBFAFEEEFGFGABdAFEGFEDDDEFEFAdFAFABdefaecdABGFFEFDDDDdefgafdfafdfaaafedefgfededefgggedefgafdfafdfabagffeedABGFFEFDDDD
# [['D', [0, 2], 'E', 'F', [3, 2], 'A', 'd', [6, 2], 'F', 'B', [9, 3], 'E', [16, 2], 'F', 'G', [19, 2], 'A', 'B', 'd', [14, 3], [20, 2], 'E', [0, 12], [23, 3], 'e', 'f', 'a', 'e', 'c', [25, 2], 'B', [20, 2], [4, 3], [0, 3], 'D', [46, 3], 'g', 'a', 'f', 'd', [48, 2], [69, 4], [76, 2], 'f', 'e', [64, 4], [79, 4], [64, 4], [92, 2], [80, 5], [68, 9], 'b', 'a', [84, 2], [79, 2], [80, 2], [53, 11]], ['D', 'DD', 'E', 'F', 'EF', 'A', 'd', 'FA', 'F', 'B', 'FAF', 'E', 'EE', 'F', 'G', 'FG', 'A', 'B', 'd', 'AFE', 'GF', 'E', 'DDDEFEFAdFAF', 'ABd', 'e', 'f', 'a', 'e', 'c', 'dA', 'B', 'GF', 'FEF', 'DDD', 'D', 'def', 'g', 'a', 'f', 'd', 'fa', 'fdfa', 'aa', 'f', 'e', 'defg', 'fede', 'defg', 'gg', 'edefg', 'afdfafdfa', 'b', 'a', 'gf', 'fe', 'ed', 'ABGFFEFDDDD'], 'DDDEFEFAdFAFBFAFEEEFGFGABdAFEGFEDDDEFEFAdFAFABdefaecdABGFFEFDDDDdefgafdfafdfaaafedefgfededefgggedefgafdfafdfabagffeedABGFFEFDDDD']
# 57 57 128
# DFAF GFEF|D2 FA dABG|F2 AF GFGB|AGFD EB,CD|DF F2 GFEF|DEFA dABG|F2 AF GFGB|AGFD ED D2:|fd d2 g2 ag|f2 df edBA|fefa gfec|dcde fddA|dfaf gfeg|fAdf edBA|GABG FAdB|AGFD ED D2:|
# DFAFGFEF|D2FAdABG|F2AFGFGB|AGFDEB,CD|DFF2GFEF|DEFAdABG|F2AFGFGB|AGFDEDD2:|fdd2g2ag|f2dfedBA|fefagfec|dcdefddA|dfafgfeg|fAdfedBA|GABGFAdB|AGFDEDD2:|
# 2
# DFAFGFEFDDFAdABGFFAFGFGBAGFDEB,CDDFFFGFEFDEFAdABGFFAFGFGBAGFDEDDDfdddggagffdfedBAfefagfecdcdefddAdfafgfegfAdfedBAGABGFAdBAGFDEDDD
# DFAFGFEFDDFAdABGFFAFGFGBAGFDEB,CDDFFFGFEFDEFAdABGFFAFGFGBAGFDEDDDfdddggagffdfedBAfefagfecdcdefddAdfafgfegfAdfedBAGABGFAdBAGFDEDDD
# ['D', 'F', 'A', 'F', 'G', 'F', 'E', 'F', 'D', [0, 3], 'd', 'A', 'B', [4, 2], [1, 5], 'G', 'B', 'A', [4, 2], 'D', 'E', 'B', ',', 'C', [8, 3], [16, 2], [4, 5], [6, 2], [11, 18], [8, 2], 'D', 'f', 'd', [66, 2], 'g', 'g', 'a', 'g', 'f', [65, 2], 'f', 'e', 'd', [23, 2], [76, 2], 'f', [71, 3], 'e', 'c', 'd', [88, 2], [82, 2], [66, 2], [11, 2], [83, 2], 'f', [85, 3], [72, 2], [96, 3], [77, 4], 'G', [13, 4], [11, 2], [56, 9]]
# ['D', 'F', 'A', 'F', 'G', 'F', 'E', 'F', 'D', 'DFA', 'd', 'A', 'B', 'GF', 'FAFGF', 'G', 'B', 'A', 'GF', 'D', 'E', 'B', ',', 'C', 'DDF', 'FF', 'GFEFD', 'EF', 'AdABGFFAFGFGBAGFDE', 'DD', 'D', 'f', 'd', 'dd', 'g', 'g', 'a', 'g', 'f', 'fd', 'f', 'e', 'd', 'BA', 'fe', 'f', 'agf', 'e', 'c', 'd', 'cd', 'ef', 'dd', 'Ad', 'fa', 'f', 'gfe', 'gf', 'Adf', 'edBA', 'G', 'ABGF', 'Ad', 'BAGFDEDDD']
# DFAFGFEFDDFAdABGFFAFGFGBAGFDEB,CDDFFFGFEFDEFAdABGFFAFGFGBAGFDEDDDfdddggagffdfedBAfefagfecdcdefddAdfafgfegfAdfedBAGABGFAdBAGFDEDDD
# [['D', 'F', 'A', 'F', 'G', 'F', 'E', 'F', 'D', [0, 3], 'd', 'A', 'B', [4, 2], [1, 5], 'G', 'B', 'A', [4, 2], 'D', 'E', 'B', ',', 'C', [8, 3], [16, 2], [4, 5], [6, 2], [11, 18], [8, 2], 'D', 'f', 'd', [66, 2], 'g', 'g', 'a', 'g', 'f', [65, 2], 'f', 'e', 'd', [23, 2], [76, 2], 'f', [71, 3], 'e', 'c', 'd', [88, 2], [82, 2], [66, 2], [11, 2], [83, 2], 'f', [85, 3], [72, 2], [96, 3], [77, 4], 'G', [13, 4], [11, 2], [56, 9]], ['D', 'F', 'A', 'F', 'G', 'F', 'E', 'F', 'D', 'DFA', 'd', 'A', 'B', 'GF', 'FAFGF', 'G', 'B', 'A', 'GF', 'D', 'E', 'B', ',', 'C', 'DDF', 'FF', 'GFEFD', 'EF', 'AdABGFFAFGFGBAGFDE', 'DD', 'D', 'f', 'd', 'dd', 'g', 'g', 'a', 'g', 'f', 'fd', 'f', 'e', 'd', 'BA', 'fe', 'f', 'agf', 'e', 'c', 'd', 'cd', 'ef', 'dd', 'Ad', 'fa', 'f', 'gfe', 'gf', 'Adf', 'edBA', 'G', 'ABGF', 'Ad', 'BAGFDEDDD'], 'DFAFGFEFDDFAdABGFFAFGFGBAGFDEB,CDDFFFGFEFDEFAdABGFFAFGFGBAGFDEDDDfdddggagffdfedBAfefagfecdcdefddAdfafgfegfAdfedBAGABGFAdBAGFDEDDD']
# 64 64 129
# |EAAG A2Bd|eg~g2 egdc|BGGF GAGE|D2B,D GABG|EAAG A2Bd|eg~g2 egdg|eg~g2 dgba|gedB BAAA||a2ea ageg|agbg agef|gedc BGBd|~g3a bgeg|a2ea ageg|agbg ageg|dg~g2 dgba|gedB BAAA|
# |EAAGA2Bd|eg~g2egdc|BGGFGAGE|D2B,DGABG|EAAGA2Bd|eg~g2egdg|eg~g2dgba|gedBBAAA||a2eaageg|agbgagef|gedcBGBd|~g3abgeg|a2eaageg|agbgageg|dg~g2dgba|gedBBAAA|
# A
# EAAGAABdegggegdcBGGFGAGEDDB,DGABGEAAGAABdegggegdgegggdgbagedBBAAAaaeaagegagbgagefgedcBGBdgggabgegaaeaagegagbgagegdgggdgbagedBBAAA
# EAAGAABdegggegdcBGGFGAGEDDB,DGABGEAAGAABdegggegdgegggdgbagedBBAAAaaeaagegagbgagefgedcBGBdgggabgegaaeaagegagbgagegdgggdgbagedBBAAA
# ['E', 'A', 'A', 'G', [1, 2], 'B', 'd', 'e', 'g', [9, 2], [8, 2], 'd', 'c', 'B', 'G', 'G', 'F', [3, 2], 'G', 'E', 'D', 'D', 'B', ',', 'D', [3, 2], [16, 2], [0, 15], [11, 3], [9, 2], [47, 2], 'b', 'a', [11, 2], 'd', 'B', 'B', [1, 2], 'A', 'a', 'a', 'e', [65, 2], [11, 3], [56, 2], 'b', [72, 3], 'e', 'f', [57, 3], [15, 3], [6, 2], [9, 3], 'a', [75, 2], [71, 3], [66, 14], [46, 3], [51, 14]]
# ['E', 'A', 'A', 'G', 'AA', 'B', 'd', 'e', 'g', 'gg', 'eg', 'd', 'c', 'B', 'G', 'G', 'F', 'GA', 'G', 'E', 'D', 'D', 'B', ',', 'D', 'GA', 'BG', 'EAAGAABdegggegd', 'geg', 'gg', 'dg', 'b', 'a', 'ge', 'd', 'B', 'B', 'AA', 'A', 'a', 'a', 'e', 'aa', 'geg', 'ag', 'b', 'gag', 'e', 'f', 'ged', 'cBG', 'Bd', 'ggg', 'a', 'bg', 'ega', 'aeaagegagbgage', 'gdg', 'ggdgbagedBBAAA']
# EAAGAABdegggegdcBGGFGAGEDDB,DGABGEAAGAABdegggegdgegggdgbagedBBAAAaaeaagegagbgagefgedcBGBdgggabgegaaeaagegagbgagegdgggdgbagedBBAAA
# [['E', 'A', 'A', 'G', [1, 2], 'B', 'd', 'e', 'g', [9, 2], [8, 2], 'd', 'c', 'B', 'G', 'G', 'F', [3, 2], 'G', 'E', 'D', 'D', 'B', ',', 'D', [3, 2], [16, 2], [0, 15], [11, 3], [9, 2], [47, 2], 'b', 'a', [11, 2], 'd', 'B', 'B', [1, 2], 'A', 'a', 'a', 'e', [65, 2], [11, 3], [56, 2], 'b', [72, 3], 'e', 'f', [57, 3], [15, 3], [6, 2], [9, 3], 'a', [75, 2], [71, 3], [66, 14], [46, 3], [51, 14]], ['E', 'A', 'A', 'G', 'AA', 'B', 'd', 'e', 'g', 'gg', 'eg', 'd', 'c', 'B', 'G', 'G', 'F', 'GA', 'G', 'E', 'D', 'D', 'B', ',', 'D', 'GA', 'BG', 'EAAGAABdegggegd', 'geg', 'gg', 'dg', 'b', 'a', 'ge', 'd', 'B', 'B', 'AA', 'A', 'a', 'a', 'e', 'aa', 'geg', 'ag', 'b', 'gag', 'e', 'f', 'ged', 'cBG', 'Bd', 'ggg', 'a', 'bg', 'ega', 'aeaagegagbgage', 'gdg', 'ggdgbagedBBAAA'], 'EAAGAABdegggegdcBGGFGAGEDDB,DGABGEAAGAABdegggegdgegggdgbagedBBAAAaaeaagegagbgagefgedcBGBdgggabgegaaeaagegagbgagegdgggdgbagedBBAAA']
# 59 59 129
# |BEED E2DE|GEDB, D2B,D|GEED E2DE|GABG ABGA|BE~E2 B,E~E2|GEDB, D2B,D|GEED E2DE|GABG AGEF||G2GF GBdc|B2BA BcBA|GFGB dedB|(3ABA GB A2(3DEF|G2FA GBdc|B2Ac BcBA|GFGB dedB|(3ABA GB A4||
# |BEEDE2DE|GEDB,D2B,D|GEEDE2DE|GABGABGA|BE~E2B,E~E2|GEDB,D2B,D|GEEDE2DE|GABGAGEF||G2GFGBdc|B2BABcBA|GFGBdedB|(3ABAGBA2(3DEF|G2FAGBdc|B2AcBcBA|GFGBdedB|(3ABAGBA4||
# 4
# BEEDEEDEGEDB,DDB,DGEEDEEDEGABGABGABEEEB,EEEGEDB,DDB,DGEEDEEDEGABGAGEFGGGFGBdcBBBABcBAGFGBdedBAAGBAADFGGFAGBdcBBAcBcBAGFGBdedBAAGBAAAA
# BEEDEEDEGEDB,DDB,DGEEDEEDEGABGABGABEEEB,EEEGEDB,DDB,DGEEDEEDEGABGAGEFGGGFGBdcBBBABcBAGFGBdedBAAGBAADFGGFAGBdcBBAcBcBAGFGBdedBAAGBAAAA
# ['B', 'E', 'E', 'D', [1, 4], 'G', [2, 2], 'B', ',', 'D', [10, 4], [8, 2], [2, 7], 'A', 'B', [26, 6], [1, 2], 'E', [11, 2], [35, 3], [8, 23], [8, 2], 'F', 'G', [69, 2], [68, 2], 'B', 'd', 'c', 'B', [77, 2], [27, 2], [76, 2], [65, 2], [72, 4], 'e', 'd', [79, 2], [65, 2], [92, 3], 'D', [68, 3], 'F', [94, 3], [75, 4], 'A', [76, 2], [82, 17], [93, 2]]
# ['B', 'E', 'E', 'D', 'EEDE', 'G', 'ED', 'B', ',', 'D', 'DB,D', 'GE', 'EDEEDEG', 'A', 'B', 'GABGAB', 'EE', 'E', 'B,', 'EEE', 'GEDB,DDB,DGEEDEEDEGABGA', 'GE', 'F', 'G', 'GG', 'FG', 'B', 'd', 'c', 'B', 'BB', 'AB', 'cB', 'AG', 'FGBd', 'e', 'd', 'BA', 'AG', 'BAA', 'D', 'FGG', 'F', 'AGB', 'dcBB', 'A', 'cB', 'cBAGFGBdedBAAGBAA', 'AA']
# BEEDEEDEGEDB,DDB,DGEEDEEDEGABGABGABEEEB,EEEGEDB,DDB,DGEEDEEDEGABGAGEFGGGFGBdcBBBABcBAGFGBdedBAAGBAADFGGFAGBdcBBAcBcBAGFGBdedBAAGBAAAA
# [['B', 'E', 'E', 'D', [1, 4], 'G', [2, 2], 'B', ',', 'D', [10, 4], [8, 2], [2, 7], 'A', 'B', [26, 6], [1, 2], 'E', [11, 2], [35, 3], [8, 23], [8, 2], 'F', 'G', [69, 2], [68, 2], 'B', 'd', 'c', 'B', [77, 2], [27, 2], [76, 2], [65, 2], [72, 4], 'e', 'd', [79, 2], [65, 2], [92, 3], 'D', [68, 3], 'F', [94, 3], [75, 4], 'A', [76, 2], [82, 17], [93, 2]], ['B', 'E', 'E', 'D', 'EEDE', 'G', 'ED', 'B', ',', 'D', 'DB,D', 'GE', 'EDEEDEG', 'A', 'B', 'GABGAB', 'EE', 'E', 'B,', 'EEE', 'GEDB,DDB,DGEEDEEDEGABGA', 'GE', 'F', 'G', 'GG', 'FG', 'B', 'd', 'c', 'B', 'BB', 'AB', 'cB', 'AG', 'FGBd', 'e', 'd', 'BA', 'AG', 'BAA', 'D', 'FGG', 'F', 'AGB', 'dcBB', 'A', 'cB', 'cBAGFGBdedBAAGBAA', 'AA'], 'BEEDEEDEGEDB,DDB,DGEEDEEDEGABGABGABEEEB,EEEGEDB,DDB,DGEEDEEDEGABGAGEFGGGFGBdcBBBABcBAGFGBdedBAAGBAADFGGFAGBdcBBAcBcBAGFGBdedBAAGBAAAA']
# 49 49 133
# |:E3F GFGA|Be ~e2 Be ~e2|E3F GABG|A2 BA GEED|E3F GFGA|Beed e3f|(3gfe fd edBG|A2 BA GE E2:||:gfeg fede|Be ~e2 Be ~e2|gfeg fedB|A2 BA GEE f|g2 eg fede|Beed e3f|(3gfe fd edBG|A2 BA GE E2:|
# |:E3FGFGA|Be~e2Be~e2|E3FGABG|A2BAGEED|E3FGFGA|Beede3f|(3gfefdedBG|A2BAGEE2:||:gfegfede|Be~e2Be~e2|gfegfedB|A2BAGEEf|g2egfede|Beede3f|(3gfefdedBG|A2BAGEE2:|
# 2
# EEEFGFGABeeeBeeeEEEFGABGAABAGEEDEEEFGFGABeedeeefgefdedBGAABAGEEEgfegfedeBeeeBeeegfegfedBAABAGEEfggegfedeBeedeeefgefdedBGAABAGEEE
# EEEFGFGABeeeBeeeEEEFGABGAABAGEEDEEEFGFGABeedeeefgefdedBGAABAGEEEgfegfedeBeeeBeeegfegfedBAABAGEEfggegfedeBeedeeefgefdedBGAABAGEEE
# ['E', [0, 2], 'F', 'G', [3, 2], 'A', 'B', 'e', [9, 2], [8, 4], [0, 5], [7, 2], [6, 2], [7, 2], 'A', 'G', [0, 2], 'D', [0, 11], 'd', [9, 3], 'f', 'g', [46, 2], [43, 2], 'd', [22, 9], 'E', 'g', 'f', 'e', [64, 3], [43, 2], [8, 8], [64, 7], [26, 2], [25, 6], [47, 2], [48, 2], [67, 8], [43, 21]]
# ['E', 'EE', 'F', 'G', 'FG', 'A', 'B', 'e', 'ee', 'Beee', 'EEEFG', 'AB', 'GA', 'AB', 'A', 'G', 'EE', 'D', 'EEEFGFGABee', 'd', 'eee', 'f', 'g', 'ef', 'de', 'd', 'BGAABAGEE', 'E', 'g', 'f', 'e', 'gfe', 'de', 'BeeeBeee', 'gfegfed', 'BA', 'ABAGEE', 'fg', 'ge', 'gfedeBee', 'deeefgefdedBGAABAGEEE']
# EEEFGFGABeeeBeeeEEEFGABGAABAGEEDEEEFGFGABeedeeefgefdedBGAABAGEEEgfegfedeBeeeBeeegfegfedBAABAGEEfggegfedeBeedeeefgefdedBGAABAGEEE
# [['E', [0, 2], 'F', 'G', [3, 2], 'A', 'B', 'e', [9, 2], [8, 4], [0, 5], [7, 2], [6, 2], [7, 2], 'A', 'G', [0, 2], 'D', [0, 11], 'd', [9, 3], 'f', 'g', [46, 2], [43, 2], 'd', [22, 9], 'E', 'g', 'f', 'e', [64, 3], [43, 2], [8, 8], [64, 7], [26, 2], [25, 6], [47, 2], [48, 2], [67, 8], [43, 21]], ['E', 'EE', 'F', 'G', 'FG', 'A', 'B', 'e', 'ee', 'Beee', 'EEEFG', 'AB', 'GA', 'AB', 'A', 'G', 'EE', 'D', 'EEEFGFGABee', 'd', 'eee', 'f', 'g', 'ef', 'de', 'd', 'BGAABAGEE', 'E', 'g', 'f', 'e', 'gfe', 'de', 'BeeeBeee', 'gfegfed', 'BA', 'ABAGEE', 'fg', 'ge', 'gfedeBee', 'deeefgefdedBGAABAGEEE'], 'EEEFGFGABeeeBeeeEEEFGABGAABAGEEDEEEFGFGABeedeeefgefdedBGAABAGEEEgfegfedeBeeeBeeegfegfedBAABAGEEfggegfedeBeedeeefgefdedBGAABAGEEE']
# 41 41 128
# |:B2Bd BAFA|B2Bd BAFA|AF (3FFF DF (3FFF|AFdB AFEF|B2Bd BAFA|B2Bd BAFA|AFAB dcdf|edef d3z:||:e2ec d2Bd|efec dFAB|e2ec d3e|fedB ADFA|e2ef eB (3BBB|gB (3BBB defg|afbf afef|gedB ADFA:|
# |:B2BdBAFA|B2BdBAFA|AF(3FFFDF(3FFF|AFdBAFEF|B2BdBAFA|B2BdBAFA|AFABdcdf|edefd3z:||:e2ecd2Bd|efecdFAB|e2ecd3e|fedBADFA|e2efeB(3BBB|gB(3BBBdefg|afbfafef|gedBADFA:|
# A
# BBBdBAFABBBdBAFAAFFFDFFFAFdBAFEFBBBdBAFABBBdBAFAAFABdcdfedefdddzeeecddBdefecdFABeeecdddefedBADFAeeefeBBBgBBBdefgafbfafefgedBADFA
# BBBdBAFABBBdBAFAAFFFDFFFAFdBAFEFBBBdBAFABBBdBAFAAFABdcdfedefdddzeeecddBdefecdFABeeecdddefedBADFAeeefeBBBgBBBdefgafbfafefgedBADFA
# ['B', [0, 2], 'd', 'B', 'A', 'F', 'A', [0, 8], [5, 2], [17, 2], 'D', [17, 3], [5, 2], [3, 4], 'E', 'F', [0, 18], [7, 2], 'd', 'c', 'd', 'f', 'e', 'd', 'e', 'f', 'd', [60, 2], 'z', 'e', [64, 2], [53, 2], [3, 2], [57, 3], [66, 3], [6, 3], [64, 6], [71, 4], [3, 3], [20, 2], 'A', [64, 3], [55, 2], [0, 3], 'g', [0, 4], [58, 2], 'g', 'a', 'f', 'b', 'f', [112, 2], [109, 3], [89, 7]]
# ['B', 'BB', 'd', 'B', 'A', 'F', 'A', 'BBBdBAFA', 'AF', 'FF', 'D', 'FFF', 'AF', 'dBAF', 'E', 'F', 'BBBdBAFABBBdBAFAAF', 'AB', 'd', 'c', 'd', 'f', 'e', 'd', 'e', 'f', 'd', 'dd', 'z', 'e', 'ee', 'cd', 'dB', 'def', 'ecd', 'FAB', 'eeecdd', 'defe', 'dBA', 'DF', 'A', 'eee', 'fe', 'BBB', 'g', 'BBBd', 'ef', 'g', 'a', 'f', 'b', 'f', 'af', 'efg', 'edBADFA']
# BBBdBAFABBBdBAFAAFFFDFFFAFdBAFEFBBBdBAFABBBdBAFAAFABdcdfedefdddzeeecddBdefecdFABeeecdddefedBADFAeeefeBBBgBBBdefgafbfafefgedBADFA
# [['B', [0, 2], 'd', 'B', 'A', 'F', 'A', [0, 8], [5, 2], [17, 2], 'D', [17, 3], [5, 2], [3, 4], 'E', 'F', [0, 18], [7, 2], 'd', 'c', 'd', 'f', 'e', 'd', 'e', 'f', 'd', [60, 2], 'z', 'e', [64, 2], [53, 2], [3, 2], [57, 3], [66, 3], [6, 3], [64, 6], [71, 4], [3, 3], [20, 2], 'A', [64, 3], [55, 2], [0, 3], 'g', [0, 4], [58, 2], 'g', 'a', 'f', 'b', 'f', [112, 2], [109, 3], [89, 7]], ['B', 'BB', 'd', 'B', 'A', 'F', 'A', 'BBBdBAFA', 'AF', 'FF', 'D', 'FFF', 'AF', 'dBAF', 'E', 'F', 'BBBdBAFABBBdBAFAAF', 'AB', 'd', 'c', 'd', 'f', 'e', 'd', 'e', 'f', 'd', 'dd', 'z', 'e', 'ee', 'cd', 'dB', 'def', 'ecd', 'FAB', 'eeecdd', 'defe', 'dBA', 'DF', 'A', 'eee', 'fe', 'BBB', 'g', 'BBBd', 'ef', 'g', 'a', 'f', 'b', 'f', 'af', 'efg', 'edBADFA'], 'BBBdBAFABBBdBAFAAFFFDFFFAFdBAFEFBBBdBAFABBBdBAFAAFABdcdfedefdddzeeecddBdefecdFABeeecdddefedBADFAeeefeBBBgBBBdefgafbfafefgedBADFA']
# 55 55 128
# e2AB cdec|d2BG DGBd|e2AB cdef|gedg eAAG|E2AB cdec|d2BG DGBd|e2AB cdef|gedg eAAe|a2ea aged|cdef g2fg|a2ea agab|gedB BAAe|a2ea aged|cdef g2ga|ba~a2 agef|gedB BAAG|
# e2ABcdec|d2BGDGBd|e2ABcdef|gedgeAAG|E2ABcdec|d2BGDGBd|e2ABcdef|gedgeAAe|a2eaaged|cdefg2fg|a2eaagab|gedBBAAe|a2eaaged|cdefg2ga|ba~a2agef|gedBBAAG|
# G
# eeABcdecddBGDGBdeeABcdefgedgeAAGEEABcdecddBGDGBdeeABcdefgedgeAAeaaeaagedcdefggfgaaeaagabgedBBAAeaaeaagedcdefgggabaaaagefgedBBAAG
# eeABcdecddBGDGBdeeABcdefgedgeAAGEEABcdecddBGDGBdeeABcdefgedgeAAeaaeaagedcdefggfgaaeaagabgedBBAAeaaeaagedcdefgggabaaaagefgedBBAAG
# ['e', 'e', 'A', 'B', 'c', 'd', 'e', [4, 2], 'd', 'B', 'G', 'D', 'G', 'B', [5, 2], [1, 6], 'f', 'g', 'e', 'd', [24, 2], 'A', 'A', 'G', 'E', 'E', [2, 29], 'e', 'a', 'a', [63, 3], [24, 3], [20, 5], 'g', [23, 2], [64, 6], 'a', 'b', [24, 3], 'B', 'B', [61, 17], [85, 3], [64, 2], [67, 4], [23, 4], [91, 4], 'G']
# ['e', 'e', 'A', 'B', 'c', 'd', 'e', 'cd', 'd', 'B', 'G', 'D', 'G', 'B', 'de', 'eABcde', 'f', 'g', 'e', 'd', 'ge', 'A', 'A', 'G', 'E', 'E', 'ABcdecddBGDGBdeeABcdefgedgeAA', 'e', 'a', 'a', 'eaa', 'ged', 'cdefg', 'g', 'fg', 'aaeaag', 'a', 'b', 'ged', 'B', 'B', 'AAeaaeaagedcdefgg', 'gab', 'aa', 'aage', 'fged', 'BBAA', 'G']
# eeABcdecddBGDGBdeeABcdefgedgeAAGEEABcdecddBGDGBdeeABcdefgedgeAAeaaeaagedcdefggfgaaeaagabgedBBAAeaaeaagedcdefgggabaaaagefgedBBAAG
# [['e', 'e', 'A', 'B', 'c', 'd', 'e', [4, 2], 'd', 'B', 'G', 'D', 'G', 'B', [5, 2], [1, 6], 'f', 'g', 'e', 'd', [24, 2], 'A', 'A', 'G', 'E', 'E', [2, 29], 'e', 'a', 'a', [63, 3], [24, 3], [20, 5], 'g', [23, 2], [64, 6], 'a', 'b', [24, 3], 'B', 'B', [61, 17], [85, 3], [64, 2], [67, 4], [23, 4], [91, 4], 'G'], ['e', 'e', 'A', 'B', 'c', 'd', 'e', 'cd', 'd', 'B', 'G', 'D', 'G', 'B', 'de', 'eABcde', 'f', 'g', 'e', 'd', 'ge', 'A', 'A', 'G', 'E', 'E', 'ABcdecddBGDGBdeeABcdefgedgeAA', 'e', 'a', 'a', 'eaa', 'ged', 'cdefg', 'g', 'fg', 'aaeaag', 'a', 'b', 'ged', 'B', 'B', 'AAeaaeaagedcdefgg', 'gab', 'aa', 'aage', 'fged', 'BBAA', 'G'], 'eeABcdecddBGDGBdeeABcdefgedgeAAGEEABcdecddBGDGBdeeABcdefgedgeAAeaaeaagedcdefggfgaaeaagabgedBBAAeaaeaagedcdefgggabaaaagefgedBBAAG']
# 48 48 128
# |~f2dg ~f2dg|~f2dB cdeg|~f2df gfed|cABc dfag|fAdg fAdg|fAdB cdeg|(3fga df gfed|cABc d2~f2|aAdf bagf|(3gfe ce aeAg|fdBd gfed|cABc d2~f2|a2 (3fga bagf|(3gfe ce Aceg|fdBd gfed|cA (3GFE D4||
# |~f2dg~f2dg|~f2dBcdeg|~f2dfgfed|cABcdfag|fAdgfAdg|fAdBcdeg|(3fgadfgfed|cABcd2~f2|aAdfbagf|(3gfeceaeAg|fdBdgfed|cABcd2~f2|a2(3fgabagf|(3gfeceAceg|fdBdgfed|cA(3GFED4||
# 4
# ffdgffdgffdBcdegffdfgfedcABcdfagfAdgfAdgfAdBcdegfadfgfedcABcddffaAdfbagfgeceaeAgfdBdgfedcABcddffaafabagfgeceAcegfdBdgfedcAGEDDDD
# ffdgffdgffdBcdegffdfgfedcABcdfagfAdgfAdgfAdBcdegfadfgfedcABcddffaAdfbagfgeceaeAgfdBdgfedcABcddffaafabagfgeceAcegfdBdgfedcAGEDDDD
# ['f', 'f', 'd', 'g', [0, 7], 'B', 'c', 'd', 'e', [3, 4], 'f', [3, 2], 'e', 'd', 'c', 'A', [11, 3], 'f', 'a', [3, 2], 'A', [2, 3], [33, 6], [11, 6], 'a', [18, 11], [18, 2], [29, 2], [33, 2], 'f', 'b', [30, 3], 'g', 'e', 'c', 'e', 'a', 'e', 'A', [3, 2], [10, 2], [2, 3], [54, 11], 'a', [29, 2], [68, 8], 'A', [74, 2], [79, 11], 'G', 'E', 'D', [124, 3]]
# ['f', 'f', 'd', 'g', 'ffdgffd', 'B', 'c', 'd', 'e', 'gffd', 'f', 'gf', 'e', 'd', 'c', 'A', 'Bcd', 'f', 'a', 'gf', 'A', 'dgf', 'AdgfAd', 'Bcdegf', 'a', 'dfgfedcABcd', 'df', 'fa', 'Ad', 'f', 'b', 'agf', 'g', 'e', 'c', 'e', 'a', 'e', 'A', 'gf', 'dB', 'dgf', 'edcABcddffa', 'a', 'fa', 'bagfgece', 'A', 'ce', 'gfdBdgfedcA', 'G', 'E', 'D', 'DDD']
# ffdgffdgffdBcdegffdfgfedcABcdfagfAdgfAdgfAdBcdegfadfgfedcABcddffaAdfbagfgeceaeAgfdBdgfedcABcddffaafabagfgeceAcegfdBdgfedcAGEDDDD
# [['f', 'f', 'd', 'g', [0, 7], 'B', 'c', 'd', 'e', [3, 4], 'f', [3, 2], 'e', 'd', 'c', 'A', [11, 3], 'f', 'a', [3, 2], 'A', [2, 3], [33, 6], [11, 6], 'a', [18, 11], [18, 2], [29, 2], [33, 2], 'f', 'b', [30, 3], 'g', 'e', 'c', 'e', 'a', 'e', 'A', [3, 2], [10, 2], [2, 3], [54, 11], 'a', [29, 2], [68, 8], 'A', [74, 2], [79, 11], 'G', 'E', 'D', [124, 3]], ['f', 'f', 'd', 'g', 'ffdgffd', 'B', 'c', 'd', 'e', 'gffd', 'f', 'gf', 'e', 'd', 'c', 'A', 'Bcd', 'f', 'a', 'gf', 'A', 'dgf', 'AdgfAd', 'Bcdegf', 'a', 'dfgfedcABcd', 'df', 'fa', 'Ad', 'f', 'b', 'agf', 'g', 'e', 'c', 'e', 'a', 'e', 'A', 'gf', 'dB', 'dgf', 'edcABcddffa', 'a', 'fa', 'bagfgece', 'A', 'ce', 'gfdBdgfedcA', 'G', 'E', 'D', 'DDD'], 'ffdgffdgffdBcdegffdfgfedcABcdfagfAdgfAdgfAdBcdegfadfgfedcABcddffaAdfbagfgeceaeAgfdBdgfedcABcddffaafabagfgeceAcegfdBdgfedcAGEDDDD']
# 53 53 128
# |:GEDE G3A|B2BA Bcd2|GEDE G3B|AGAB AGE2|GEDE G2GA|B2BA Bcd2|edef gedc|BGAF G4:||:g3e f3d|edef edB2|gedB G2GB|AGAB AGE2|GEDE G2GA|B3A Bcd2|edef gedc|BGAF G4:|
# |:GEDEG3A|B2BABcd2|GEDEG3B|AGABAGE2|GEDEG2GA|B2BABcd2|edefgedc|BGAFG4:||:g3ef3d|edefedB2|gedBG2GB|AGABAGE2|GEDEG2GA|B3ABcd2|edefgedc|BGAFG4:|
# 4
# GEDEGGGABBBABcddGEDEGGGBAGABAGEEGEDEGGGABBBABcddedefgedcBGAFGGGGgggefffdedefedBBgedBGGGBAGABAGEEGEDEGGGABBBABcddedefgedcBGAFGGGG
# GEDEGGGABBBABcddGEDEGGGBAGABAGEEGEDEGGGABBBABcddedefgedcBGAFGGGGgggefffdedefedBBgedBGGGBAGABAGEEGEDEGGGABBBABcddedefgedcBGAFGGGG
# ['G', 'E', 'D', 'E', 'G', [4, 2], 'A', 'B', [8, 2], [7, 2], 'c', 'd', 'd', [0, 7], [10, 2], [6, 3], [24, 2], 'E', [3, 2], [1, 15], 'e', [47, 2], 'f', 'g', [48, 2], 'c', 'B', [6, 2], 'F', [4, 3], 'G', 'g', [64, 2], [50, 2], [68, 2], [47, 5], [48, 2], [8, 2], [52, 3], [56, 2], [21, 43]]
# ...
# 2
# BBeBgBeBccecgcecddfdadfdgfedBeedBBeBgBeBccecgcecddfdadfdgfedBeeeeBBBGBEBeBBBGBEBdAAAFAAAdAAAdefdeBBBGBEBeBBBGBEBcccBcdefgefdBeee
# BBeBgBeBccecgcecddfdadfdgfedBeedBBeBgBeBccecgcecddfdadfdgfedBeeeeBBBGBEBeBBBGBEBdAAAFAAAdAAAdefdeBBBGBEBeBBBGBEBcccBcdefgefdBeee
# ['B', 'B', 'e', 'B', 'g', [1, 3], 'c', 'c', 'e', 'c', 'g', [9, 3], 'd', 'd', 'f', 'd', 'a', [17, 3], 'g', 'f', 'e', 'd', [1, 2], [26, 3], [1, 30], [29, 2], [0, 2], 'B', 'G', 'B', 'E', [1, 3], [66, 6], 'd', 'A', [81, 2], 'F', [81, 3], [80, 4], 'd', 'e', [18, 2], [64, 16], [8, 2], 'c', [7, 2], [92, 3], 'g', [93, 3], [60, 4]]
# ['B', 'B', 'e', 'B', 'g', 'BeB', 'c', 'c', 'e', 'c', 'g', 'cec', 'd', 'd', 'f', 'd', 'a', 'dfd', 'g', 'f', 'e', 'd', 'Be', 'edB', 'BeBgBeBccecgcecddfdadfdgfedBee', 'ee', 'BB', 'B', 'G', 'B', 'E', 'BeB', 'BBGBEB', 'd', 'A', 'AA', 'F', 'AAA', 'dAAA', 'd', 'e', 'fd', 'eBBBGBEBeBBBGBEB', 'cc', 'c', 'Bc', 'def', 'g', 'efd', 'Beee']
# BBeBgBeBccecgcecddfdadfdgfedBeedBBeBgBeBccecgcecddfdadfdgfedBeeeeBBBGBEBeBBBGBEBdAAAFAAAdAAAdefdeBBBGBEBeBBBGBEBcccBcdefgefdBeee
# [['B', 'B', 'e', 'B', 'g', [1, 3], 'c', 'c', 'e', 'c', 'g', [9, 3], 'd', 'd', 'f', 'd', 'a', [17, 3], 'g', 'f', 'e', 'd', [1, 2], [26, 3], [1, 30], [29, 2], [0, 2], 'B', 'G', 'B', 'E', [1, 3], [66, 6], 'd', 'A', [81, 2], 'F', [81, 3], [80, 4], 'd', 'e', [18, 2], [64, 16], [8, 2], 'c', [7, 2], [92, 3], 'g', [93, 3], [60, 4]], ['B', 'B', 'e', 'B', 'g', 'BeB', 'c', 'c', 'e', 'c', 'g', 'cec', 'd', 'd', 'f', 'd', 'a', 'dfd', 'g', 'f', 'e', 'd', 'Be', 'edB', 'BeBgBeBccecgcecddfdadfdgfedBee', 'ee', 'BB', 'B', 'G', 'B', 'E', 'BeB', 'BBGBEB', 'd', 'A', 'AA', 'F', 'AAA', 'dAAA', 'd', 'e', 'fd', 'eBBBGBEBeBBBGBEB', 'cc', 'c', 'Bc', 'def', 'g', 'efd', 'Beee'], 'BBeBgBeBccecgcecddfdadfdgfedBeedBBeBgBeBccecgcecddfdadfdgfedBeeeeBBBGBEBeBBBGBEBdAAAFAAAdAAAdefdeBBBGBEBeBBBGBEBcccBcdefgefdBeee']
# 50 50 128
# |Eeed e2 BA|GBAF GFEF|Dddc d2 AF|GBAG FDDF|Eeed efge|fedf edBA|GABG FGA=c|BGAF GE EE:|gfef (3gfe be|gebe gfef|d2 fd adfd|ABAG FDDF|(3GGG BG (3FFF AF|Eeef gfed|B2 dB AGFA|BGAF GE EE:|
# |Eeede2BA|GBAFGFEF|Dddcd2AF|GBAGFDDF|Eeedefge|fedfedBA|GABGFGA=c|BGAFGEEE:|gfef(3gfebe|gebegfef|d2fdadfd|ABAGFDDF|(3GGGBG(3FFFAF|Eeefgfed|B2dBAGFA|BGAFGEEE:|
# E
# EeedeeBAGBAFGFEFDddcddAFGBAGFDDFEeedefgefedfedBAGABGFGA=cBGAFGEEEgfefgebegebegfefddfdadfdABAGFDDFGGBGFFAFEeefgfedBBdBAGFABGAFGEEE
# EeedeeBAGBAFGFEFDddcddAFGBAGFDDFEeedefgefedfedBAGABGFGA=cBGAFGEEEgfefgebegebegfefddfdadfdABAGFDDFGGBGFFAFEeefgfedBBdBAGFABGAFGEEE
# ['E', 'e', 'e', 'd', [1, 2], 'B', 'A', 'G', [6, 2], 'F', 'G', 'F', 'E', 'F', 'D', 'd', 'd', 'c', [17, 2], [10, 3], [6, 3], [15, 2], 'D', [13, 2], [1, 4], 'f', 'g', [36, 2], [2, 2], [40, 3], [6, 3], 'A', 'B', [12, 2], [48, 2], '=', 'c', [50, 2], [10, 3], 'E', [62, 2], 'g', [40, 2], [37, 3], 'b', 'e', [69, 5], [66, 3], [17, 2], [80, 2], 'a', [82, 3], [49, 2], [26, 6], 'G', [8, 2], [12, 2], 'F', [10, 2], [0, 3], [37, 2], [43, 4], 'B', [45, 4], [102, 2], [57, 8]]
# ['E', 'e', 'e', 'd', 'ee', 'B', 'A', 'G', 'BA', 'F', 'G', 'F', 'E', 'F', 'D', 'd', 'd', 'c', 'dd', 'AFG', 'BAG', 'FD', 'D', 'FE', 'eede', 'f', 'g', 'ef', 'ed', 'fed', 'BAG', 'A', 'B', 'GF', 'GA', '=', 'c', 'BG', 'AFG', 'E', 'EE', 'g', 'fe', 'fge', 'b', 'e', 'gebeg', 'fef', 'dd', 'fd', 'a', 'dfd', 'AB', 'AGFDDF', 'G', 'GB', 'GF', 'F', 'AF', 'Eee', 'fg', 'fedB', 'B', 'dBAG', 'FA', 'BGAFGEEE']
# EeedeeBAGBAFGFEFDddcddAFGBAGFDDFEeedefgefedfedBAGABGFGA=cBGAFGEEEgfefgebegebegfefddfdadfdABAGFDDFGGBGFFAFEeefgfedBBdBAGFABGAFGEEE
# [['E', 'e', 'e', 'd', [1, 2], 'B', 'A', 'G', [6, 2], 'F', 'G', 'F', 'E', 'F', 'D', 'd', 'd', 'c', [17, 2], [10, 3], [6, 3], [15, 2], 'D', [13, 2], [1, 4], 'f', 'g', [36, 2], [2, 2], [40, 3], [6, 3], 'A', 'B', [12, 2], [48, 2], '=', 'c', [50, 2], [10, 3], 'E', [62, 2], 'g', [40, 2], [37, 3], 'b', 'e', [69, 5], [66, 3], [17, 2], [80, 2], 'a', [82, 3], [49, 2], [26, 6], 'G', [8, 2], [12, 2], 'F', [10, 2], [0, 3], [37, 2], [43, 4], 'B', [45, 4], [102, 2], [57, 8]], ['E', 'e', 'e', 'd', 'ee', 'B', 'A', 'G', 'BA', 'F', 'G', 'F', 'E', 'F', 'D', 'd', 'd', 'c', 'dd', 'AFG', 'BAG', 'FD', 'D', 'FE', 'eede', 'f', 'g', 'ef', 'ed', 'fed', 'BAG', 'A', 'B', 'GF', 'GA', '=', 'c', 'BG', 'AFG', 'E', 'EE', 'g', 'fe', 'fge', 'b', 'e', 'gebeg', 'fef', 'dd', 'fd', 'a', 'dfd', 'AB', 'AGFDDF', 'G', 'GB', 'GF', 'F', 'AF', 'Eee', 'fg', 'fedB', 'B', 'dBAG', 'FA', 'BGAFGEEE'], 'EeedeeBAGBAFGFEFDddcddAFGBAGFDDFEeedefgefedfedBAGABGFGA=cBGAFGEEEgfefgebegebegfefddfdadfdABAGFDDFGGBGFFAFEeefgfedBBdBAGFABGAFGEEE']
# 66 66 129
# G2 BG cABG|AD D2 FGAF|G2 BG cABG|Addc BGGF|G3B c3B|AD D2 FGAF|G3B cABG|Addc BGGf||g2dg egde|g2dg eaaf|g2dg egdB|cAdc BGGf|g2dg egde|g2dg eaaf|g2dg egdB|cAdc BGGF||
# G2BGcABG|ADD2FGAF|G2BGcABG|AddcBGGF|G3Bc3B|ADD2FGAF|G3BcABG|AddcBGGf||g2dgegde|g2dgeaaf|g2dgegdB|cAdcBGGf|g2dgegde|g2dgeaaf|g2dgegdB|cAdcBGGF||
# F
# GGBGcABGADDDFGAFGGBGcABGAddcBGGFGGGBcccBADDDFGAFGGGBcABGAddcBGGfggdgegdeggdgeaafggdgegdBcAdcBGGfggdgegdeggdgeaafggdgegdBcAdcBGGF
# GGBGcABGADDDFGAFGGBGcABGAddcBGGFGGGBcccBADDDFGAFGGGBcABGAddcBGGfggdgegdeggdgeaafggdgegdBcAdcBGGfggdgegdeggdgeaafggdgegdBcAdcBGGF
# ['G', 'G', 'B', 'G', 'c', 'A', [2, 2], 'A', 'D', [9, 2], 'F', [7, 2], [12, 2], [1, 8], 'd', 'd', 'c', [2, 2], 'G', [15, 3], [1, 2], 'c', [36, 2], 'B', [8, 10], [34, 3], [21, 10], 'f', 'g', 'g', 'd', 'g', 'e', [65, 2], [68, 2], [65, 4], 'a', 'a', [63, 8], [51, 3], [58, 37], 'F']
# ['G', 'G', 'B', 'G', 'c', 'A', 'BG', 'A', 'D', 'DD', 'F', 'GA', 'FG', 'GBGcABGA', 'd', 'd', 'c', 'BG', 'G', 'FGG', 'GB', 'c', 'cc', 'B', 'ADDDFGAFGG', 'GBc', 'ABGAddcBGG', 'f', 'g', 'g', 'd', 'g', 'e', 'gd', 'eg', 'gdge', 'a', 'a', 'fggdgegd', 'BcA', 'dcBGGfggdgegdeggdgeaafggdgegdBcAdcBGG', 'F']
# GGBGcABGADDDFGAFGGBGcABGAddcBGGFGGGBcccBADDDFGAFGGGBcABGAddcBGGfggdgegdeggdgeaafggdgegdBcAdcBGGfggdgegdeggdgeaafggdgegdBcAdcBGGF
# [['G', 'G', 'B', 'G', 'c', 'A', [2, 2], 'A', 'D', [9, 2], 'F', [7, 2], [12, 2], [1, 8], 'd', 'd', 'c', [2, 2], 'G', [15, 3], [1, 2], 'c', [36, 2], 'B', [8, 10], [34, 3], [21, 10], 'f', 'g', 'g', 'd', 'g', 'e', [65, 2], [68, 2], [65, 4], 'a', 'a', [63, 8], [51, 3], [58, 37], 'F'], ['G', 'G', 'B', 'G', 'c', 'A', 'BG', 'A', 'D', 'DD', 'F', 'GA', 'FG', 'GBGcABGA', 'd', 'd', 'c', 'BG', 'G', 'FGG', 'GB', 'c', 'cc', 'B', 'ADDDFGAFGG', 'GBc', 'ABGAddcBGG', 'f', 'g', 'g', 'd', 'g', 'e', 'gd', 'eg', 'gdge', 'a', 'a', 'fggdgegd', 'BcA', 'dcBGGfggdgegdeggdgeaafggdgegdBcAdcBGG', 'F'], 'GGBGcABGADDDFGAFGGBGcABGAddcBGGFGGGBcccBADDDFGAFGGGBcABGAddcBGGfggdgegdeggdgeaafggdgegdBcAdcBGGfggdgegdeggdgeaafggdgegdBcAdcBGGF']
# 42 42 128
# FBBB dBBA|FBBA FEFA|BEEE BABc|dffe dBAG|EBBB d2BA|FBBA FEFA|BEEE BABc|dffe dBAG:|Beed e2de|fede fe e2|feb2 fede|fede fe e2|Beed efge|fede fa a2|abba faaf|effe dBA2:|
# FBBBdBBA|FBBAFEFA|BEEEBABc|dffedBAG|EBBBd2BA|FBBAFEFA|BEEEBABc|dffedBAG:|Beede2de|fedefee2|feb2fede|fedefee2|Beedefge|fedefaa2|abbafaaf|effedBA2:|
# 2
# FBBBdBBAFBBAFEFABEEEBABcdffedBAGEBBBddBAFBBAFEFABEEEBABcdffedBAGBeedeedefedefeeefebbfedefedefeeeBeedefgefedefaaaabbafaafeffedBAA
# FBBBdBBAFBBAFEFABEEEBABcdffedBAGEBBBddBAFBBAFEFABEEEBABcdffedBAGBeedeedefedefeeefebbfedefedefeeeBeedefgefedefaaaabbafaafeffedBAA
# ['F', 'B', [1, 2], 'd', [1, 2], 'A', [0, 3], [7, 2], 'E', 'F', 'A', 'B', 'E', [17, 2], [6, 2], 'B', 'c', 'd', 'f', 'f', 'e', [4, 2], 'A', 'G', [19, 2], [2, 3], [28, 3], [8, 24], 'B', 'e', [27, 2], [65, 4], [26, 3], [71, 3], [65, 2], [26, 2], 'b', 'b', [72, 6], [74, 6], [64, 5], 'f', 'g', [71, 6], 'a', [109, 3], [82, 2], 'a', [108, 3], [26, 2], [25, 6], 'A']
# ['F', 'B', 'BB', 'd', 'BB', 'A', 'FBB', 'AF', 'E', 'F', 'A', 'B', 'E', 'EE', 'BA', 'B', 'c', 'd', 'f', 'f', 'e', 'dB', 'A', 'G', 'EB', 'BBd', 'dBA', 'FBBAFEFABEEEBABcdffedBAG', 'B', 'e', 'ed', 'eede', 'fed', 'efe', 'ee', 'fe', 'b', 'b', 'fedefe', 'defeee', 'Beede', 'f', 'g', 'efedef', 'a', 'aaa', 'bb', 'a', 'faa', 'fe', 'ffedBA', 'A']
# FBBBdBBAFBBAFEFABEEEBABcdffedBAGEBBBddBAFBBAFEFABEEEBABcdffedBAGBeedeedefedefeeefebbfedefedefeeeBeedefgefedefaaaabbafaafeffedBAA
# [['F', 'B', [1, 2], 'd', [1, 2], 'A', [0, 3], [7, 2], 'E', 'F', 'A', 'B', 'E', [17, 2], [6, 2], 'B', 'c', 'd', 'f', 'f', 'e', [4, 2], 'A', 'G', [19, 2], [2, 3], [28, 3], [8, 24], 'B', 'e', [27, 2], [65, 4], [26, 3], [71, 3], [65, 2], [26, 2], 'b', 'b', [72, 6], [74, 6], [64, 5], 'f', 'g', [71, 6], 'a', [109, 3], [82, 2], 'a', [108, 3], [26, 2], [25, 6], 'A'], ['F', 'B', 'BB', 'd', 'BB', 'A', 'FBB', 'AF', 'E', 'F', 'A', 'B', 'E', 'EE', 'BA', 'B', 'c', 'd', 'f', 'f', 'e', 'dB', 'A', 'G', 'EB', 'BBd', 'dBA', 'FBBAFEFABEEEBABcdffedBAG', 'B', 'e', 'ed', 'eede', 'fed', 'efe', 'ee', 'fe', 'b', 'b', 'fedefe', 'defeee', 'Beede', 'f', 'g', 'efedef', 'a', 'aaa', 'bb', 'a', 'faa', 'fe', 'ffedBA', 'A'], 'FBBBdBBAFBBAFEFABEEEBABcdffedBAGEBBBddBAFBBAFEFABEEEBABcdffedBAGBeedeedefedefeeefebbfedefedefeeeBeedefgefedefaaaabbafaafeffedBAA']
# 52 52 128
# A2AB AFED|B2BA BcdB|A2AB AFED|gfed BcdB|A2AB AFED|B2BA BcdB|A2AB AFED|gfed Bcde||f2fd g2ge|f2fd Bcde|f2fd g2fg|afed Bcde|f2fd g2ge|f2fd Bcde|defg a2ab|afed BcdB||
# A2ABAFED|B2BABcdB|A2ABAFED|gfedBcdB|A2ABAFED|B2BABcdB|A2ABAFED|gfedBcde||f2fdg2ge|f2fdBcde|f2fdg2fg|afedBcde|f2fdg2ge|f2fdBcde|defga2ab|afedBcdB||
# B
# AAABAFEDBBBABcdBAAABAFEDgfedBcdBAAABAFEDBBBABcdBAAABAFEDgfedBcdefffdgggefffdBcdefffdggfgafedBcdefffdgggefffdBcdedefgaaabafedBcdB
# AAABAFEDBBBABcdBAAABAFEDgfedBcdBAAABAFEDBBBABcdBAAABAFEDgfedBcdefffdgggefffdBcdefffdggfgafedBcdefffdgggefffdBcdedefgaaabafedBcdB
# ['A', [0, 2], 'B', 'A', 'F', 'E', 'D', 'B', [8, 2], [2, 2], 'c', 'd', [3, 2], [1, 7], 'g', 'f', 'e', [14, 2], [13, 11], [8, 23], 'e', 'f', [64, 2], 'd', 'g', [68, 2], [63, 5], [60, 10], 'f', 'g', 'a', [57, 23], [62, 3], [87, 2], [116, 2], 'b', [88, 7], 'B']
# ['A', 'AA', 'B', 'A', 'F', 'E', 'D', 'B', 'BB', 'AB', 'c', 'd', 'BA', 'AABAFED', 'g', 'f', 'e', 'dB', 'cdBAAABAFED', 'BBBABcdBAAABAFEDgfedBcd', 'e', 'f', 'ff', 'd', 'g', 'gg', 'efffd', 'Bcdefffdgg', 'f', 'g', 'a', 'fedBcdefffdgggefffdBcde', 'def', 'ga', 'aa', 'b', 'afedBcd', 'B']
# AAABAFEDBBBABcdBAAABAFEDgfedBcdBAAABAFEDBBBABcdBAAABAFEDgfedBcdefffdgggefffdBcdefffdggfgafedBcdefffdgggefffdBcdedefgaaabafedBcdB
# [['A', [0, 2], 'B', 'A', 'F', 'E', 'D', 'B', [8, 2], [2, 2], 'c', 'd', [3, 2], [1, 7], 'g', 'f', 'e', [14, 2], [13, 11], [8, 23], 'e', 'f', [64, 2], 'd', 'g', [68, 2], [63, 5], [60, 10], 'f', 'g', 'a', [57, 23], [62, 3], [87, 2], [116, 2], 'b', [88, 7], 'B'], ['A', 'AA', 'B', 'A', 'F', 'E', 'D', 'B', 'BB', 'AB', 'c', 'd', 'BA', 'AABAFED', 'g', 'f', 'e', 'dB', 'cdBAAABAFED', 'BBBABcdBAAABAFEDgfedBcd', 'e', 'f', 'ff', 'd', 'g', 'gg', 'efffd', 'Bcdefffdgg', 'f', 'g', 'a', 'fedBcdefffdgggefffdBcde', 'def', 'ga', 'aa', 'b', 'afedBcd', 'B'], 'AAABAFEDBBBABcdBAAABAFEDgfedBcdBAAABAFEDBBBABcdBAAABAFEDgfedBcdefffdgggefffdBcdefffdggfgafedBcdefffdgggefffdBcdedefgaaabafedBcdB']
# 38 38 128
# |:F2FG FEDE|FAAB AFED|d2eg fdec|dBAG BEED|F2FG FEDE|FAAB AFED|d2eg fdec|dBAG FDDD:||:d2AG FDFA|dfaf gfeg|fedf eAcA|dfed cA A2|BAGB ADFD|dfaf gfed|Bdce dBAG|FGEF D4:|
# |:F2FGFEDE|FAABAFED|d2egfdec|dBAGBEED|F2FGFEDE|FAABAFED|d2egfdec|dBAGFDDD:||:d2AGFDFA|dfafgfeg|fedfeAcA|dfedcAA2|BAGBADFD|dfafgfed|BdcedBAG|FGEFD4:|
# 4
# FFFGFEDEFAABAFEDddegfdecdBAGBEEDFFFGFEDEFAABAFEDddegfdecdBAGFDDDddAGFDFAdfafgfegfedfeAcAdfedcAAABAGBADFDdfafgfedBdcedBAGFGEFDDDD
# FFFGFEDEFAABAFEDddegfdecdBAGBEEDFFFGFEDEFAABAFEDddegfdecdBAGFDDDddAGFDFAdfafgfegfedfeAcAdfedcAAABAGBADFDdfafgfedBdcedBAGFGEFDDDD
# ['F', [0, 2], 'G', 'F', 'E', 'D', 'E', 'F', 'A', 'A', 'B', 'A', [4, 3], 'd', 'd', 'e', 'g', 'f', [17, 2], 'c', 'd', [11, 2], 'G', 'B', 'E', [5, 2], [0, 28], 'F', 'D', [61, 2], [16, 2], [58, 4], [8, 2], 'd', 'f', 'a', 'f', [19, 2], [18, 3], 'e', [72, 2], 'e', 'A', 'c', [71, 3], [81, 2], [86, 2], [9, 4], [27, 2], 'A', [31, 2], [15, 2], [73, 6], [24, 2], [91, 2], [110, 3], [58, 3], 'G', [7, 2], [61, 3], 'D']
# ['F', 'FF', 'G', 'F', 'E', 'D', 'E', 'F', 'A', 'A', 'B', 'A', 'FED', 'd', 'd', 'e', 'g', 'f', 'de', 'c', 'd', 'BA', 'G', 'B', 'E', 'ED', 'FFFGFEDEFAABAFEDddegfdecdBAG', 'F', 'D', 'DD', 'dd', 'AGFD', 'FA', 'd', 'f', 'a', 'f', 'gf', 'egf', 'e', 'df', 'e', 'A', 'c', 'Adf', 'ed', 'cA', 'AABA', 'GB', 'A', 'DF', 'Dd', 'fafgfe', 'dB', 'dc', 'edB', 'AGF', 'G', 'EF', 'DDD', 'D']
# FFFGFEDEFAABAFEDddegfdecdBAGBEEDFFFGFEDEFAABAFEDddegfdecdBAGFDDDddAGFDFAdfafgfegfedfeAcAdfedcAAABAGBADFDdfafgfedBdcedBAGFGEFDDDD
# [['F', [0, 2], 'G', 'F', 'E', 'D', 'E', 'F', 'A', 'A', 'B', 'A', [4, 3], 'd', 'd', 'e', 'g', 'f', [17, 2], 'c', 'd', [11, 2], 'G', 'B', 'E', [5, 2], [0, 28], 'F', 'D', [61, 2], [16, 2], [58, 4], [8, 2], 'd', 'f', 'a', 'f', [19, 2], [18, 3], 'e', [72, 2], 'e', 'A', 'c', [71, 3], [81, 2], [86, 2], [9, 4], [27, 2], 'A', [31, 2], [15, 2], [73, 6], [24, 2], [91, 2], [110, 3], [58, 3], 'G', [7, 2], [61, 3], 'D'], ['F', 'FF', 'G', 'F', 'E', 'D', 'E', 'F', 'A', 'A', 'B', 'A', 'FED', 'd', 'd', 'e', 'g', 'f', 'de', 'c', 'd', 'BA', 'G', 'B', 'E', 'ED', 'FFFGFEDEFAABAFEDddegfdecdBAG', 'F', 'D', 'DD', 'dd', 'AGFD', 'FA', 'd', 'f', 'a', 'f', 'gf', 'egf', 'e', 'df', 'e', 'A', 'c', 'Adf', 'ed', 'cA', 'AABA', 'GB', 'A', 'DF', 'Dd', 'fafgfe', 'dB', 'dc', 'edB', 'AGF', 'G', 'EF', 'DDD', 'D'], 'FFFGFEDEFAABAFEDddegfdecdBAGBEEDFFFGFEDEFAABAFEDddegfdecdBAGFDDDddAGFDFAdfafgfegfedfeAcAdfedcAAABAGBADFDdfafgfedBdcedBAGFGEFDDDD']
# 61 61 128
# |:DBBA B2BA|GABd eBdB|(3ABA GB A2(3Bcd|eB(3BAB eBdB|DBBA B2BA|GABd eBdB|GABG (3ABA GA|BGAG EGD2:||:f2fd edBd|edge dABd|f2fd edBd|eaag ea(3aba|f2fd edBd|g2ge dcBA|GABG (3ABA GA|BGAG EGD2:|
# |:DBBAB2BA|GABdeBdB|(3ABAGBA2(3Bcd|eB(3BABeBdB|DBBAB2BA|GABdeBdB|GABG(3ABAGA|BGAGEGD2:||:f2fdedBd|edgedABd|f2fdedBd|eaagea(3aba|f2fdedBd|g2gedcBA|GABG(3ABAGA|BGAGEGD2:|
# 2
# DBBABBBAGABdeBdBAAGBAABdeBBBeBdBDBBABBBAGABdeBdBGABGAAGABGAGEGDDfffdedBdedgedABdfffdedBdeaageaaafffdedBdgggedcBAGABGAAGABGAGEGDD
# DBBABBBAGABdeBdBAAGBAABdeBBBeBdBDBBABBBAGABdeBdBGABGAAGABGAGEGDDfffdedBdedgedABdfffdedBdeaageaaafffdedBdgggedcBAGABGAAGABGAGEGDD
# ['D', 'B', 'B', 'A', [1, 2], [2, 2], 'G', [3, 2], 'd', 'e', [10, 2], [2, 2], [7, 2], [15, 3], [10, 4], [1, 2], [12, 4], [0, 16], [8, 3], [8, 2], [7, 4], [8, 2], 'G', 'E', 'G', 'D', 'D', 'f', [64, 2], [11, 2], [14, 2], [67, 3], 'g', [68, 2], [9, 3], [64, 9], 'a', 'a', [74, 2], [89, 2], 'a', [64, 8], 'g', [104, 2], [68, 2], 'c', [6, 5], [51, 13]]
# ['D', 'B', 'B', 'A', 'BB', 'BA', 'G', 'AB', 'd', 'e', 'Bd', 'BA', 'AG', 'BAA', 'BdeB', 'BB', 'eBdB', 'DBBABBBAGABdeBdB', 'GAB', 'GA', 'AGAB', 'GA', 'G', 'E', 'G', 'D', 'D', 'f', 'ff', 'de', 'dB', 'ded', 'g', 'ed', 'ABd', 'fffdedBde', 'a', 'a', 'ge', 'aa', 'a', 'fffdedBd', 'g', 'gg', 'ed', 'c', 'BAGAB', 'GAAGABGAGEGDD']
# DBBABBBAGABdeBdBAAGBAABdeBBBeBdBDBBABBBAGABdeBdBGABGAAGABGAGEGDDfffdedBdedgedABdfffdedBdeaageaaafffdedBdgggedcBAGABGAAGABGAGEGDD
# [['D', 'B', 'B', 'A', [1, 2], [2, 2], 'G', [3, 2], 'd', 'e', [10, 2], [2, 2], [7, 2], [15, 3], [10, 4], [1, 2], [12, 4], [0, 16], [8, 3], [8, 2], [7, 4], [8, 2], 'G', 'E', 'G', 'D', 'D', 'f', [64, 2], [11, 2], [14, 2], [67, 3], 'g', [68, 2], [9, 3], [64, 9], 'a', 'a', [74, 2], [89, 2], 'a', [64, 8], 'g', [104, 2], [68, 2], 'c', [6, 5], [51, 13]], ['D', 'B', 'B', 'A', 'BB', 'BA', 'G', 'AB', 'd', 'e', 'Bd', 'BA', 'AG', 'BAA', 'BdeB', 'BB', 'eBdB', 'DBBABBBAGABdeBdB', 'GAB', 'GA', 'AGAB', 'GA', 'G', 'E', 'G', 'D', 'D', 'f', 'ff', 'de', 'dB', 'ded', 'g', 'ed', 'ABd', 'fffdedBde', 'a', 'a', 'ge', 'aa', 'a', 'fffdedBd', 'g', 'gg', 'ed', 'c', 'BAGAB', 'GAAGABGAGEGDD'], 'DBBABBBAGABdeBdBAAGBAABdeBBBeBdBDBBABBBAGABdeBdBGABGAAGABGAGEGDDfffdedBdedgedABdfffdedBdeaageaaafffdedBdgggedcBAGABGAAGABGAGEGDD']
# 48 48 128
# [40, 39, 58, 44, 46, 40, 41, 26, 51, 46, 48, 49, 57, 41, 55, 48, 53, 41, 54, 45, 37, 46, 38, 44, 53, 36, 38, 42, 55, 52, 48, 41, 52, 55, 46, 49, 47, 43, 40, 42, 47, 41, 58, 59, 45, 49, 40, 50, 46, 46, 46, 56, 64, 52, 50, 42, 52, 38, 61, 48]
# 7.051871304050358
# 46.93333333333333
# [3.2, 3.28, 2.21, 2.91, 2.78, 3.2, 3.12, 4.92, 2.51, 2.78, 2.67, 2.61, 2.25, 3.12, 2.33, 2.67, 2.42, 3.12, 2.37, 2.84, 3.46, 2.78, 3.37, 2.91, 2.42, 3.56, 3.37, 3.05, 2.33, 2.46, 2.67, 3.12, 2.46, 2.33, 2.78, 2.61, 2.72, 2.98, 3.2, 3.05, 2.72, 3.12, 2.21, 2.17, 2.84, 2.61, 3.2, 2.56, 2.78, 2.78, 2.78, 2.29, 2.0, 2.46, 2.56, 3.05, 2.46, 3.37, 2.1, 2.67]
